# %%
from pathlib import Path

Path.ls = lambda x: list(x.iterdir())

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import platform
platform.processor()

# %%
# !python --version
# Out:
# Python 3.7.7

# %%
# !conda --version
# Out:
# conda 4.8.2

# %%
# !conda install -c conda-forge -y spacy
# !python -m spacy download en_core_web_sm

# %%
# !conda install -c anaconda -y nltk
# import nltk
# nltk.download("punkt")

# %%
# !conda install -c stanfordnlp -y stanza
# import stanza
# stanza.download("en")
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/master/resources_1.0.0.json: 116kB [00:00, 2.18MB/s]
# 2020-05-21 13:32:55 INFO: Downloading default packages for language: en (English)...
# Downloading http://nlp.stanford.edu/software/stanza/1.0.0/en/default.zip: 100%|██████████| 402M/402M [07:58<00:00, 842kB/s]
# 2020-05-21 13:41:04 INFO: Finished downloading models and saved to /Users/nirant/stanza_resources.

# %%
# !pip install tokenizers

# %% [markdown]
# # Prepare Moview Reviews Data

# %%
imdb_reviews_data_path = Path("aclImdb/")

# %%
train_data_path = imdb_reviews_data_path/"train"/"all"
test_data_path = imdb_reviews_data_path/"test"/"all"
train_data_path.ls(), test_data_path.ls()
# Out:
# ([PosixPath('aclImdb/train/all/4715_9.txt'),
#   PosixPath('aclImdb/train/all/12390_8.txt'),
#   PosixPath('aclImdb/train/all/8329_7.txt'),
#   PosixPath('aclImdb/train/all/1821_4.txt'),
#   PosixPath('aclImdb/train/all/18512_0.txt'),
#   PosixPath('aclImdb/train/all/37594_0.txt'),
#   PosixPath('aclImdb/train/all/1597_0.txt'),
#   PosixPath('aclImdb/train/all/27082_0.txt'),
#   PosixPath('aclImdb/train/all/20592_0.txt'),
#   PosixPath('aclImdb/train/all/30084_0.txt'),
#   PosixPath('aclImdb/train/all/6087_0.txt'),
#   PosixPath('aclImdb/train/all/10402_1.txt'),
#   PosixPath('aclImdb/train/all/1062_4.txt'),
#   PosixPath('aclImdb/train/all/49665_0.txt'),
#   PosixPath('aclImdb/train/all/9063_8.txt'),
#   PosixPath('aclImdb/train/all/25725_0.txt'),
#   PosixPath('aclImdb/train/all/18980_0.txt'),
#   PosixPath('aclImdb/train/all/20143_0.txt'),
#   PosixPath('aclImdb/train/all/35233_0.txt'),
#   PosixPath('aclImdb/train/all/6456_0.txt'),
#   PosixPath('aclImdb/train/all/9056_1.txt'),
#   PosixPath('aclImdb/train/all/30455_0.txt'),
#   PosixPath('aclImdb/train/all/3230_0.txt'),
#   PosixPath('aclImdb/train/all/1905_0.txt'),
#   PosixPath('aclImdb/train/all/37906_0.txt'),
#   PosixPath('aclImdb/train/all/5392_3.txt'),
#   PosixPath('aclImdb/train/all/3092_10.txt'),
#   PosixPath('aclImdb/train/all/2682_3.txt'),
#   PosixPath('aclImdb/train/all/20900_0.txt'),
#   PosixPath('aclImdb/train/all/32723_0.txt'),
#   PosixPath('aclImdb/train/all/1146_0.txt'),
#   PosixPath('aclImdb/train/all/37145_0.txt'),
#   PosixPath('aclImdb/train/all/4720_0.txt'),
#   PosixPath('aclImdb/train/all/22235_0.txt'),
#   PosixPath('aclImdb/train/all/27453_0.txt'),
#   PosixPath('aclImdb/train/all/3351_4.txt'),
#   PosixPath('aclImdb/train/all/399_2.txt'),
#   PosixPath('aclImdb/train/all/6881_0.txt'),
#   PosixPath('aclImdb/train/all/30882_0.txt'),
#   PosixPath('aclImdb/train/all/18557_0.txt'),
#   PosixPath('aclImdb/train/all/9865_8.txt'),
#   PosixPath('aclImdb/train/all/6639_10.txt'),
#   PosixPath('aclImdb/train/all/10460_10.txt'),
#   PosixPath('aclImdb/train/all/10331_10.txt'),
#   PosixPath('aclImdb/train/all/11606_10.txt'),
#   PosixPath('aclImdb/train/all/6168_10.txt'),
#   PosixPath('aclImdb/train/all/27884_0.txt'),
#   PosixPath('aclImdb/train/all/10447_1.txt'),
#   PosixPath('aclImdb/train/all/38738_0.txt'),
#   PosixPath('aclImdb/train/all/49620_0.txt'),
#   PosixPath('aclImdb/train/all/2712_10.txt'),
#   PosixPath('aclImdb/train/all/3225_10.txt'),
#   PosixPath('aclImdb/train/all/41508_0.txt'),
#   PosixPath('aclImdb/train/all/10096_1.txt'),
#   PosixPath('aclImdb/train/all/37943_0.txt'),
#   PosixPath('aclImdb/train/all/1940_0.txt'),
#   PosixPath('aclImdb/train/all/20106_0.txt'),
#   PosixPath('aclImdb/train/all/25760_0.txt'),
#   PosixPath('aclImdb/train/all/3275_0.txt'),
#   PosixPath('aclImdb/train/all/30410_0.txt'),
#   PosixPath('aclImdb/train/all/12509_0.txt'),
#   PosixPath('aclImdb/train/all/6413_0.txt'),
#   PosixPath('aclImdb/train/all/35276_0.txt'),
#   PosixPath('aclImdb/train/all/4765_0.txt'),
#   PosixPath('aclImdb/train/all/37100_0.txt'),
#   PosixPath('aclImdb/train/all/1103_0.txt'),
#   PosixPath('aclImdb/train/all/15019_0.txt'),
#   PosixPath('aclImdb/train/all/32766_0.txt'),
#   PosixPath('aclImdb/train/all/27416_0.txt'),
#   PosixPath('aclImdb/train/all/22270_0.txt'),
#   PosixPath('aclImdb/train/all/9850_1.txt'),
#   PosixPath('aclImdb/train/all/18186_0.txt'),
#   PosixPath('aclImdb/train/all/20945_0.txt'),
#   PosixPath('aclImdb/train/all/46018_0.txt'),
#   PosixPath('aclImdb/train/all/3574_10.txt'),
#   PosixPath('aclImdb/train/all/4392_3.txt'),
#   PosixPath('aclImdb/train/all/3192_10.txt'),
#   PosixPath('aclImdb/train/all/36906_0.txt'),
#   PosixPath('aclImdb/train/all/19980_0.txt'),
#   PosixPath('aclImdb/train/all/21143_0.txt'),
#   PosixPath('aclImdb/train/all/24725_0.txt'),
#   PosixPath('aclImdb/train/all/2230_0.txt'),
#   PosixPath('aclImdb/train/all/31455_0.txt'),
#   PosixPath('aclImdb/train/all/7456_0.txt'),
#   PosixPath('aclImdb/train/all/8056_1.txt'),
#   PosixPath('aclImdb/train/all/34233_0.txt'),
#   PosixPath('aclImdb/train/all/5720_0.txt'),
#   PosixPath('aclImdb/train/all/36145_0.txt'),
#   PosixPath('aclImdb/train/all/33723_0.txt'),
#   PosixPath('aclImdb/train/all/26453_0.txt'),
#   PosixPath('aclImdb/train/all/11890_1.txt'),
#   PosixPath('aclImdb/train/all/23235_0.txt'),
#   PosixPath('aclImdb/train/all/21900_0.txt'),
#   PosixPath('aclImdb/train/all/556_0.txt'),
#   PosixPath('aclImdb/train/all/716_10.txt'),
#   PosixPath('aclImdb/train/all/36594_0.txt'),
#   PosixPath('aclImdb/train/all/26082_0.txt'),
#   PosixPath('aclImdb/train/all/19512_0.txt'),
#   PosixPath('aclImdb/train/all/6435_3.txt'),
#   PosixPath('aclImdb/train/all/3253_3.txt'),
#   PosixPath('aclImdb/train/all/187_0.txt'),
#   PosixPath('aclImdb/train/all/1125_3.txt'),
#   PosixPath('aclImdb/train/all/5518_1.txt'),
#   PosixPath('aclImdb/train/all/21592_0.txt'),
#   PosixPath('aclImdb/train/all/7087_0.txt'),
#   PosixPath('aclImdb/train/all/8487_1.txt'),
#   PosixPath('aclImdb/train/all/31084_0.txt'),
#   PosixPath('aclImdb/train/all/48665_0.txt'),
#   PosixPath('aclImdb/train/all/40508_0.txt'),
#   PosixPath('aclImdb/train/all/24760_0.txt'),
#   PosixPath('aclImdb/train/all/21106_0.txt'),
#   PosixPath('aclImdb/train/all/34276_0.txt'),
#   PosixPath('aclImdb/train/all/13509_0.txt'),
#   PosixPath('aclImdb/train/all/7413_0.txt'),
#   PosixPath('aclImdb/train/all/8013_1.txt'),
#   PosixPath('aclImdb/train/all/31410_0.txt'),
#   PosixPath('aclImdb/train/all/2275_0.txt'),
#   PosixPath('aclImdb/train/all/36943_0.txt'),
#   PosixPath('aclImdb/train/all/9248_3.txt'),
#   PosixPath('aclImdb/train/all/2612_10.txt'),
#   PosixPath('aclImdb/train/all/5568_8.txt'),
#   PosixPath('aclImdb/train/all/6554_7.txt'),
#   PosixPath('aclImdb/train/all/1807_7.txt'),
#   PosixPath('aclImdb/train/all/10424_2.txt'),
#   PosixPath('aclImdb/train/all/513_0.txt'),
#   PosixPath('aclImdb/train/all/3474_10.txt'),
#   PosixPath('aclImdb/train/all/19186_0.txt'),
#   PosixPath('aclImdb/train/all/21945_0.txt'),
#   PosixPath('aclImdb/train/all/33766_0.txt'),
#   PosixPath('aclImdb/train/all/14019_0.txt'),
#   PosixPath('aclImdb/train/all/36100_0.txt'),
#   PosixPath('aclImdb/train/all/5765_0.txt'),
#   PosixPath('aclImdb/train/all/23270_0.txt'),
#   PosixPath('aclImdb/train/all/26416_0.txt'),
#   PosixPath('aclImdb/train/all/2780_4.txt'),
#   PosixPath('aclImdb/train/all/47018_0.txt'),
#   PosixPath('aclImdb/train/all/6470_3.txt'),
#   PosixPath('aclImdb/train/all/11057_10.txt'),
#   PosixPath('aclImdb/train/all/31882_0.txt'),
#   PosixPath('aclImdb/train/all/7881_0.txt'),
#   PosixPath('aclImdb/train/all/19557_0.txt'),
#   PosixPath('aclImdb/train/all/26884_0.txt'),
#   PosixPath('aclImdb/train/all/39738_0.txt'),
#   PosixPath('aclImdb/train/all/11447_1.txt'),
#   PosixPath('aclImdb/train/all/48620_0.txt'),
#   PosixPath('aclImdb/train/all/437_4.txt'),
#   PosixPath('aclImdb/train/all/10231_10.txt'),
#   PosixPath('aclImdb/train/all/11706_10.txt'),
#   PosixPath('aclImdb/train/all/12383_2.txt'),
#   PosixPath('aclImdb/train/all/9699_3.txt'),
#   PosixPath('aclImdb/train/all/981_0.txt'),
#   PosixPath('aclImdb/train/all/9833_2.txt'),
#   PosixPath('aclImdb/train/all/42582_0.txt'),
#   PosixPath('aclImdb/train/all/39856_0.txt'),
#   PosixPath('aclImdb/train/all/11583_0.txt'),
#   PosixPath('aclImdb/train/all/5499_0.txt'),
#   PosixPath('aclImdb/train/all/7106_1.txt'),
#   PosixPath('aclImdb/train/all/8506_0.txt'),
#   PosixPath('aclImdb/train/all/845_1.txt'),
#   PosixPath('aclImdb/train/all/10972_3.txt'),
#   PosixPath('aclImdb/train/all/11167_9.txt'),
#   PosixPath('aclImdb/train/all/803_10.txt'),
#   PosixPath('aclImdb/train/all/29503_0.txt'),
#   PosixPath('aclImdb/train/all/39015_0.txt'),
#   PosixPath('aclImdb/train/all/16093_0.txt'),
#   PosixPath('aclImdb/train/all/2189_0.txt'),
#   PosixPath('aclImdb/train/all/7945_1.txt'),
#   PosixPath('aclImdb/train/all/11076_4.txt'),
#   PosixPath('aclImdb/train/all/45092_0.txt'),
#   PosixPath('aclImdb/train/all/9565_3.txt'),
#   PosixPath('aclImdb/train/all/5245_8.txt'),
#   PosixPath('aclImdb/train/all/42910_0.txt'),
#   PosixPath('aclImdb/train/all/45443_0.txt'),
#   PosixPath('aclImdb/train/all/40225_0.txt'),
#   PosixPath('aclImdb/train/all/33808_0.txt'),
#   PosixPath('aclImdb/train/all/11911_0.txt'),
#   PosixPath('aclImdb/train/all/13224_0.txt'),
#   PosixPath('aclImdb/train/all/16442_0.txt'),
#   PosixPath('aclImdb/train/all/2558_0.txt'),
#   PosixPath('aclImdb/train/all/90_0.txt'),
#   PosixPath('aclImdb/train/all/8994_0.txt'),
#   PosixPath('aclImdb/train/all/14734_0.txt'),
#   PosixPath('aclImdb/train/all/11152_0.txt'),
#   PosixPath('aclImdb/train/all/5048_0.txt'),
#   PosixPath('aclImdb/train/all/29991_0.txt'),
#   PosixPath('aclImdb/train/all/42153_0.txt'),
#   PosixPath('aclImdb/train/all/47735_0.txt'),
#   PosixPath('aclImdb/train/all/12202_3.txt'),
#   PosixPath('aclImdb/train/all/45894_0.txt'),
#   PosixPath('aclImdb/train/all/8543_0.txt'),
#   PosixPath('aclImdb/train/all/16895_0.txt'),
#   PosixPath('aclImdb/train/all/39813_0.txt'),
#   PosixPath('aclImdb/train/all/29546_0.txt'),
#   PosixPath('aclImdb/train/all/5235_1.txt'),
#   PosixPath('aclImdb/train/all/39050_0.txt'),
#   PosixPath('aclImdb/train/all/48148_0.txt'),
#   PosixPath('aclImdb/train/all/40260_0.txt'),
#   PosixPath('aclImdb/train/all/45406_0.txt'),
#   PosixPath('aclImdb/train/all/42955_0.txt'),
#   PosixPath('aclImdb/train/all/48599_0.txt'),
#   PosixPath('aclImdb/train/all/16407_0.txt'),
#   PosixPath('aclImdb/train/all/31378_0.txt'),
#   PosixPath('aclImdb/train/all/13261_0.txt'),
#   PosixPath('aclImdb/train/all/24008_0.txt'),
#   PosixPath('aclImdb/train/all/11954_0.txt'),
#   PosixPath('aclImdb/train/all/29197_0.txt'),
#   PosixPath('aclImdb/train/all/39481_0.txt'),
#   PosixPath('aclImdb/train/all/7935_8.txt'),
#   PosixPath('aclImdb/train/all/8192_0.txt'),
#   PosixPath('aclImdb/train/all/23518_0.txt'),
#   PosixPath('aclImdb/train/all/11117_0.txt'),
#   PosixPath('aclImdb/train/all/36668_0.txt'),
#   PosixPath('aclImdb/train/all/14771_0.txt'),
#   PosixPath('aclImdb/train/all/835_8.txt'),
#   PosixPath('aclImdb/train/all/47770_0.txt'),
#   PosixPath('aclImdb/train/all/42116_0.txt'),
#   PosixPath('aclImdb/train/all/41225_0.txt'),
#   PosixPath('aclImdb/train/all/44443_0.txt'),
#   PosixPath('aclImdb/train/all/43910_0.txt'),
#   PosixPath('aclImdb/train/all/17442_0.txt'),
#   PosixPath('aclImdb/train/all/3558_0.txt'),
#   PosixPath('aclImdb/train/all/12224_0.txt'),
#   PosixPath('aclImdb/train/all/9994_0.txt'),
#   PosixPath('aclImdb/train/all/10911_0.txt'),
#   PosixPath('aclImdb/train/all/32808_0.txt'),
#   PosixPath('aclImdb/train/all/2703_2.txt'),
#   PosixPath('aclImdb/train/all/6970_8.txt'),
#   PosixPath('aclImdb/train/all/9533_9.txt'),
#   PosixPath('aclImdb/train/all/5393_10.txt'),
#   PosixPath('aclImdb/train/all/7926_2.txt'),
#   PosixPath('aclImdb/train/all/10152_0.txt'),
#   PosixPath('aclImdb/train/all/4048_0.txt'),
#   PosixPath('aclImdb/train/all/28991_0.txt'),
#   PosixPath('aclImdb/train/all/15734_0.txt'),
#   PosixPath('aclImdb/train/all/46735_0.txt'),
#   PosixPath('aclImdb/train/all/43153_0.txt'),
#   PosixPath('aclImdb/train/all/3384_8.txt'),
#   PosixPath('aclImdb/train/all/10835_4.txt'),
#   PosixPath('aclImdb/train/all/12300_4.txt'),
#   PosixPath('aclImdb/train/all/43582_0.txt'),
#   PosixPath('aclImdb/train/all/6106_1.txt'),
#   PosixPath('aclImdb/train/all/9506_0.txt'),
#   PosixPath('aclImdb/train/all/3760_1.txt'),
#   PosixPath('aclImdb/train/all/38856_0.txt'),
#   PosixPath('aclImdb/train/all/10583_0.txt'),
#   PosixPath('aclImdb/train/all/4499_0.txt'),
#   PosixPath('aclImdb/train/all/17093_0.txt'),
#   PosixPath('aclImdb/train/all/3189_0.txt'),
#   PosixPath('aclImdb/train/all/28503_0.txt'),
#   PosixPath('aclImdb/train/all/1416_1.txt'),
#   PosixPath('aclImdb/train/all/4270_1.txt'),
#   PosixPath('aclImdb/train/all/38015_0.txt'),
#   PosixPath('aclImdb/train/all/10076_4.txt'),
#   PosixPath('aclImdb/train/all/44092_0.txt'),
#   PosixPath('aclImdb/train/all/6935_8.txt'),
#   PosixPath('aclImdb/train/all/4342_10.txt'),
#   PosixPath('aclImdb/train/all/43955_0.txt'),
#   PosixPath('aclImdb/train/all/49599_0.txt'),
#   PosixPath('aclImdb/train/all/44406_0.txt'),
#   PosixPath('aclImdb/train/all/41260_0.txt'),
#   PosixPath('aclImdb/train/all/10954_0.txt'),
#   PosixPath('aclImdb/train/all/28197_0.txt'),
#   PosixPath('aclImdb/train/all/1082_1.txt'),
#   PosixPath('aclImdb/train/all/38481_0.txt'),
#   PosixPath('aclImdb/train/all/12261_0.txt'),
#   PosixPath('aclImdb/train/all/863_2.txt'),
#   PosixPath('aclImdb/train/all/30378_0.txt'),
#   PosixPath('aclImdb/train/all/17407_0.txt'),
#   PosixPath('aclImdb/train/all/25008_0.txt'),
#   PosixPath('aclImdb/train/all/22518_0.txt'),
#   PosixPath('aclImdb/train/all/15771_0.txt'),
#   PosixPath('aclImdb/train/all/37668_0.txt'),
#   PosixPath('aclImdb/train/all/10117_0.txt'),
#   PosixPath('aclImdb/train/all/12488_1.txt'),
#   PosixPath('aclImdb/train/all/6592_1.txt'),
#   PosixPath('aclImdb/train/all/9192_0.txt'),
#   PosixPath('aclImdb/train/all/43116_0.txt'),
#   PosixPath('aclImdb/train/all/46770_0.txt'),
#   PosixPath('aclImdb/train/all/9576_9.txt'),
#   PosixPath('aclImdb/train/all/11913_10.txt'),
#   PosixPath('aclImdb/train/all/5124_10.txt'),
#   PosixPath('aclImdb/train/all/44894_0.txt'),
#   PosixPath('aclImdb/train/all/38813_0.txt'),
#   PosixPath('aclImdb/train/all/9543_0.txt'),
#   PosixPath('aclImdb/train/all/17895_0.txt'),
#   PosixPath('aclImdb/train/all/10961_9.txt'),
#   PosixPath('aclImdb/train/all/28546_0.txt'),
#   PosixPath('aclImdb/train/all/38050_0.txt'),
#   PosixPath('aclImdb/train/all/6900_1.txt'),
#   PosixPath('aclImdb/train/all/49148_0.txt'),
#   PosixPath('aclImdb/train/all/44869_0.txt'),
#   PosixPath('aclImdb/train/all/22134_0.txt'),
#   PosixPath('aclImdb/train/all/27752_0.txt'),
#   PosixPath('aclImdb/train/all/32422_0.txt'),
#   PosixPath('aclImdb/train/all/1247_0.txt'),
#   PosixPath('aclImdb/train/all/37244_0.txt'),
#   PosixPath('aclImdb/train/all/4421_0.txt'),
#   PosixPath('aclImdb/train/all/35971_0.txt'),
#   PosixPath('aclImdb/train/all/17868_0.txt'),
#   PosixPath('aclImdb/train/all/3972_0.txt'),
#   PosixPath('aclImdb/train/all/11760_2.txt'),
#   PosixPath('aclImdb/train/all/2835_7.txt'),
#   PosixPath('aclImdb/train/all/9919_9.txt'),
#   PosixPath('aclImdb/train/all/5093_3.txt'),
#   PosixPath('aclImdb/train/all/22977_0.txt'),
#   PosixPath('aclImdb/train/all/35132_0.txt'),
#   PosixPath('aclImdb/train/all/6757_0.txt'),
#   PosixPath('aclImdb/train/all/30754_0.txt'),
#   PosixPath('aclImdb/train/all/3131_0.txt'),
#   PosixPath('aclImdb/train/all/25424_0.txt'),
#   PosixPath('aclImdb/train/all/20242_0.txt'),
#   PosixPath('aclImdb/train/all/9177_10.txt'),
#   PosixPath('aclImdb/train/all/2911_3.txt'),
#   PosixPath('aclImdb/train/all/5442_3.txt'),
#   PosixPath('aclImdb/train/all/6762_9.txt'),
#   PosixPath('aclImdb/train/all/49564_0.txt'),
#   PosixPath('aclImdb/train/all/30385_0.txt'),
#   PosixPath('aclImdb/train/all/6386_0.txt'),
#   PosixPath('aclImdb/train/all/20693_0.txt'),
#   PosixPath('aclImdb/train/all/27383_0.txt'),
#   PosixPath('aclImdb/train/all/37695_0.txt'),
#   PosixPath('aclImdb/train/all/28929_0.txt'),
#   PosixPath('aclImdb/train/all/1696_0.txt'),
#   PosixPath('aclImdb/train/all/18613_0.txt'),
#   PosixPath('aclImdb/train/all/12475_1.txt'),
#   PosixPath('aclImdb/train/all/12091_8.txt'),
#   PosixPath('aclImdb/train/all/4414_9.txt'),
#   PosixPath('aclImdb/train/all/9491_10.txt'),
#   PosixPath('aclImdb/train/all/46319_0.txt'),
#   PosixPath('aclImdb/train/all/3481_4.txt'),
#   PosixPath('aclImdb/train/all/18287_0.txt'),
#   PosixPath('aclImdb/train/all/3937_0.txt'),
#   PosixPath('aclImdb/train/all/35934_0.txt'),
#   PosixPath('aclImdb/train/all/27717_0.txt'),
#   PosixPath('aclImdb/train/all/22171_0.txt'),
#   PosixPath('aclImdb/train/all/4464_0.txt'),
#   PosixPath('aclImdb/train/all/37201_0.txt'),
#   PosixPath('aclImdb/train/all/1202_0.txt'),
#   PosixPath('aclImdb/train/all/15318_0.txt'),
#   PosixPath('aclImdb/train/all/32467_0.txt'),
#   PosixPath('aclImdb/train/all/3174_0.txt'),
#   PosixPath('aclImdb/train/all/30711_0.txt'),
#   PosixPath('aclImdb/train/all/12608_0.txt'),
#   PosixPath('aclImdb/train/all/6712_0.txt'),
#   PosixPath('aclImdb/train/all/9312_1.txt'),
#   PosixPath('aclImdb/train/all/35177_0.txt'),
#   PosixPath('aclImdb/train/all/20207_0.txt'),
#   PosixPath('aclImdb/train/all/25461_0.txt'),
#   PosixPath('aclImdb/train/all/22932_0.txt'),
#   PosixPath('aclImdb/train/all/41609_0.txt'),
#   PosixPath('aclImdb/train/all/6115_10.txt'),
#   PosixPath('aclImdb/train/all/7422_10.txt'),
#   PosixPath('aclImdb/train/all/49521_0.txt'),
#   PosixPath('aclImdb/train/all/9969_0.txt'),
#   PosixPath('aclImdb/train/all/38439_0.txt'),
#   PosixPath('aclImdb/train/all/3258_10.txt'),
#   PosixPath('aclImdb/train/all/6727_9.txt'),
#   PosixPath('aclImdb/train/all/9327_8.txt'),
#   PosixPath('aclImdb/train/all/4451_9.txt'),
#   PosixPath('aclImdb/train/all/3509_10.txt'),
#   PosixPath('aclImdb/train/all/12430_1.txt'),
#   PosixPath('aclImdb/train/all/18656_0.txt'),
#   PosixPath('aclImdb/train/all/1879_1.txt'),
#   PosixPath('aclImdb/train/all/48564_0.txt'),
#   PosixPath('aclImdb/train/all/7386_0.txt'),
#   PosixPath('aclImdb/train/all/8786_1.txt'),
#   PosixPath('aclImdb/train/all/31385_0.txt'),
#   PosixPath('aclImdb/train/all/28_0.txt'),
#   PosixPath('aclImdb/train/all/21693_0.txt'),
#   PosixPath('aclImdb/train/all/11703_1.txt'),
#   PosixPath('aclImdb/train/all/2389_10.txt'),
#   PosixPath('aclImdb/train/all/286_0.txt'),
#   PosixPath('aclImdb/train/all/19613_0.txt'),
#   PosixPath('aclImdb/train/all/26383_0.txt'),
#   PosixPath('aclImdb/train/all/36695_0.txt'),
#   PosixPath('aclImdb/train/all/29929_0.txt'),
#   PosixPath('aclImdb/train/all/657_0.txt'),
#   PosixPath('aclImdb/train/all/45869_0.txt'),
#   PosixPath('aclImdb/train/all/16868_0.txt'),
#   PosixPath('aclImdb/train/all/2972_0.txt'),
#   PosixPath('aclImdb/train/all/34971_0.txt'),
#   PosixPath('aclImdb/train/all/26752_0.txt'),
#   PosixPath('aclImdb/train/all/23134_0.txt'),
#   PosixPath('aclImdb/train/all/5421_0.txt'),
#   PosixPath('aclImdb/train/all/36244_0.txt'),
#   PosixPath('aclImdb/train/all/33422_0.txt'),
#   PosixPath('aclImdb/train/all/2131_0.txt'),
#   PosixPath('aclImdb/train/all/31754_0.txt'),
#   PosixPath('aclImdb/train/all/7757_0.txt'),
#   PosixPath('aclImdb/train/all/34132_0.txt'),
#   PosixPath('aclImdb/train/all/21242_0.txt'),
#   PosixPath('aclImdb/train/all/24424_0.txt'),
#   PosixPath('aclImdb/train/all/23977_0.txt'),
#   PosixPath('aclImdb/train/all/1936_10.txt'),
#   PosixPath('aclImdb/train/all/736_4.txt'),
#   PosixPath('aclImdb/train/all/6284_7.txt'),
#   PosixPath('aclImdb/train/all/7727_9.txt'),
#   PosixPath('aclImdb/train/all/48521_0.txt'),
#   PosixPath('aclImdb/train/all/39439_0.txt'),
#   PosixPath('aclImdb/train/all/8969_0.txt'),
#   PosixPath('aclImdb/train/all/19656_0.txt'),
#   PosixPath('aclImdb/train/all/1794_7.txt'),
#   PosixPath('aclImdb/train/all/2902_9.txt'),
#   PosixPath('aclImdb/train/all/3409_10.txt'),
#   PosixPath('aclImdb/train/all/47319_0.txt'),
#   PosixPath('aclImdb/train/all/9591_10.txt'),
#   PosixPath('aclImdb/train/all/23171_0.txt'),
#   PosixPath('aclImdb/train/all/26717_0.txt'),
#   PosixPath('aclImdb/train/all/33467_0.txt'),
#   PosixPath('aclImdb/train/all/14318_0.txt'),
#   PosixPath('aclImdb/train/all/36201_0.txt'),
#   PosixPath('aclImdb/train/all/5464_0.txt'),
#   PosixPath('aclImdb/train/all/19287_0.txt'),
#   PosixPath('aclImdb/train/all/34934_0.txt'),
#   PosixPath('aclImdb/train/all/2937_0.txt'),
#   PosixPath('aclImdb/train/all/612_0.txt'),
#   PosixPath('aclImdb/train/all/1059_2.txt'),
#   PosixPath('aclImdb/train/all/2379_8.txt'),
#   PosixPath('aclImdb/train/all/6655_7.txt'),
#   PosixPath('aclImdb/train/all/58_9.txt'),
#   PosixPath('aclImdb/train/all/11773_8.txt'),
#   PosixPath('aclImdb/train/all/23932_0.txt'),
#   PosixPath('aclImdb/train/all/11397_1.txt'),
#   PosixPath('aclImdb/train/all/34177_0.txt'),
#   PosixPath('aclImdb/train/all/13608_0.txt'),
#   PosixPath('aclImdb/train/all/7712_0.txt'),
#   PosixPath('aclImdb/train/all/31711_0.txt'),
#   PosixPath('aclImdb/train/all/2174_0.txt'),
#   PosixPath('aclImdb/train/all/24461_0.txt'),
#   PosixPath('aclImdb/train/all/21207_0.txt'),
#   PosixPath('aclImdb/train/all/40609_0.txt'),
#   PosixPath('aclImdb/train/all/10008_2.txt'),
#   PosixPath('aclImdb/train/all/7232_8.txt'),
#   PosixPath('aclImdb/train/all/8632_9.txt'),
#   PosixPath('aclImdb/train/all/8898_8.txt'),
#   PosixPath('aclImdb/train/all/40967_0.txt'),
#   PosixPath('aclImdb/train/all/42252_0.txt'),
#   PosixPath('aclImdb/train/all/47434_0.txt'),
#   PosixPath('aclImdb/train/all/13966_0.txt'),
#   PosixPath('aclImdb/train/all/14435_0.txt'),
#   PosixPath('aclImdb/train/all/11253_0.txt'),
#   PosixPath('aclImdb/train/all/5349_0.txt'),
#   PosixPath('aclImdb/train/all/13125_0.txt'),
#   PosixPath('aclImdb/train/all/16743_0.txt'),
#   PosixPath('aclImdb/train/all/2659_0.txt'),
#   PosixPath('aclImdb/train/all/26879_0.txt'),
#   PosixPath('aclImdb/train/all/45742_0.txt'),
#   PosixPath('aclImdb/train/all/40124_0.txt'),
#   PosixPath('aclImdb/train/all/6178_7.txt'),
#   PosixPath('aclImdb/train/all/6264_2.txt'),
#   PosixPath('aclImdb/train/all/3402_2.txt'),
#   PosixPath('aclImdb/train/all/45393_0.txt'),
#   PosixPath('aclImdb/train/all/19938_0.txt'),
#   PosixPath('aclImdb/train/all/16392_0.txt'),
#   PosixPath('aclImdb/train/all/2288_0.txt'),
#   PosixPath('aclImdb/train/all/39314_0.txt'),
#   PosixPath('aclImdb/train/all/29602_0.txt'),
#   PosixPath('aclImdb/train/all/307_1.txt'),
#   PosixPath('aclImdb/train/all/9740_7.txt'),
#   PosixPath('aclImdb/train/all/7849_9.txt'),
#   PosixPath('aclImdb/train/all/3890_2.txt'),
#   PosixPath('aclImdb/train/all/7207_1.txt'),
#   PosixPath('aclImdb/train/all/8607_0.txt'),
#   PosixPath('aclImdb/train/all/11682_0.txt'),
#   PosixPath('aclImdb/train/all/5798_0.txt'),
#   PosixPath('aclImdb/train/all/42683_0.txt'),
#   PosixPath('aclImdb/train/all/47471_0.txt'),
#   PosixPath('aclImdb/train/all/42217_0.txt'),
#   PosixPath('aclImdb/train/all/40922_0.txt'),
#   PosixPath('aclImdb/train/all/11216_0.txt'),
#   PosixPath('aclImdb/train/all/36569_0.txt'),
#   PosixPath('aclImdb/train/all/14470_0.txt'),
#   PosixPath('aclImdb/train/all/23619_0.txt'),
#   PosixPath('aclImdb/train/all/13923_0.txt'),
#   PosixPath('aclImdb/train/all/7839_0.txt'),
#   PosixPath('aclImdb/train/all/8293_0.txt'),
#   PosixPath('aclImdb/train/all/1623_10.txt'),
#   PosixPath('aclImdb/train/all/8677_9.txt'),
#   PosixPath('aclImdb/train/all/939_0.txt'),
#   PosixPath('aclImdb/train/all/39780_0.txt'),
#   PosixPath('aclImdb/train/all/29296_0.txt'),
#   PosixPath('aclImdb/train/all/24309_0.txt'),
#   PosixPath('aclImdb/train/all/16706_0.txt'),
#   PosixPath('aclImdb/train/all/31079_0.txt'),
#   PosixPath('aclImdb/train/all/13160_0.txt'),
#   PosixPath('aclImdb/train/all/48698_0.txt'),
#   PosixPath('aclImdb/train/all/40161_0.txt'),
#   PosixPath('aclImdb/train/all/45707_0.txt'),
#   PosixPath('aclImdb/train/all/342_1.txt'),
#   PosixPath('aclImdb/train/all/10275_3.txt'),
#   PosixPath('aclImdb/train/all/5708_10.txt'),
#   PosixPath('aclImdb/train/all/2629_9.txt'),
#   PosixPath('aclImdb/train/all/48249_0.txt'),
#   PosixPath('aclImdb/train/all/39351_0.txt'),
#   PosixPath('aclImdb/train/all/29647_0.txt'),
#   PosixPath('aclImdb/train/all/5977_1.txt'),
#   PosixPath('aclImdb/train/all/7242_1.txt'),
#   PosixPath('aclImdb/train/all/8642_0.txt'),
#   PosixPath('aclImdb/train/all/11223_9.txt'),
#   PosixPath('aclImdb/train/all/12103_3.txt'),
#   PosixPath('aclImdb/train/all/44393_0.txt'),
#   PosixPath('aclImdb/train/all/38314_0.txt'),
#   PosixPath('aclImdb/train/all/28602_0.txt'),
#   PosixPath('aclImdb/train/all/18938_0.txt'),
#   PosixPath('aclImdb/train/all/17392_0.txt'),
#   PosixPath('aclImdb/train/all/3288_0.txt'),
#   PosixPath('aclImdb/train/all/10682_0.txt'),
#   PosixPath('aclImdb/train/all/4798_0.txt'),
#   PosixPath('aclImdb/train/all/10828_1.txt'),
#   PosixPath('aclImdb/train/all/6207_1.txt'),
#   PosixPath('aclImdb/train/all/9607_0.txt'),
#   PosixPath('aclImdb/train/all/43683_0.txt'),
#   PosixPath('aclImdb/train/all/7980_10.txt'),
#   PosixPath('aclImdb/train/all/12480_10.txt'),
#   PosixPath('aclImdb/train/all/10266_9.txt'),
#   PosixPath('aclImdb/train/all/46434_0.txt'),
#   PosixPath('aclImdb/train/all/43252_0.txt'),
#   PosixPath('aclImdb/train/all/41967_0.txt'),
#   PosixPath('aclImdb/train/all/10253_0.txt'),
#   PosixPath('aclImdb/train/all/4349_0.txt'),
#   PosixPath('aclImdb/train/all/15435_0.txt'),
#   PosixPath('aclImdb/train/all/12966_0.txt'),
#   PosixPath('aclImdb/train/all/3454_8.txt'),
#   PosixPath('aclImdb/train/all/4907_8.txt'),
#   PosixPath('aclImdb/train/all/1988_9.txt'),
#   PosixPath('aclImdb/train/all/27879_0.txt'),
#   PosixPath('aclImdb/train/all/17743_0.txt'),
#   PosixPath('aclImdb/train/all/3659_0.txt'),
#   PosixPath('aclImdb/train/all/12125_0.txt'),
#   PosixPath('aclImdb/train/all/41124_0.txt'),
#   PosixPath('aclImdb/train/all/44742_0.txt'),
#   PosixPath('aclImdb/train/all/49249_0.txt'),
#   PosixPath('aclImdb/train/all/38351_0.txt'),
#   PosixPath('aclImdb/train/all/4134_1.txt'),
#   PosixPath('aclImdb/train/all/1752_1.txt'),
#   PosixPath('aclImdb/train/all/28647_0.txt'),
#   PosixPath('aclImdb/train/all/6951_10.txt'),
#   PosixPath('aclImdb/train/all/12166_10.txt'),
#   PosixPath('aclImdb/train/all/5159_10.txt'),
#   PosixPath('aclImdb/train/all/3424_1.txt'),
#   PosixPath('aclImdb/train/all/12358_1.txt'),
#   PosixPath('aclImdb/train/all/6242_1.txt'),
#   PosixPath('aclImdb/train/all/9642_0.txt'),
#   PosixPath('aclImdb/train/all/10858_8.txt'),
#   PosixPath('aclImdb/train/all/9677_9.txt'),
#   PosixPath('aclImdb/train/all/41922_0.txt'),
#   PosixPath('aclImdb/train/all/43217_0.txt'),
#   PosixPath('aclImdb/train/all/46471_0.txt'),
#   PosixPath('aclImdb/train/all/12923_0.txt'),
#   PosixPath('aclImdb/train/all/6839_0.txt'),
#   PosixPath('aclImdb/train/all/6693_1.txt'),
#   PosixPath('aclImdb/train/all/9293_0.txt'),
#   PosixPath('aclImdb/train/all/15470_0.txt'),
#   PosixPath('aclImdb/train/all/37569_0.txt'),
#   PosixPath('aclImdb/train/all/10216_0.txt'),
#   PosixPath('aclImdb/train/all/22619_0.txt'),
#   PosixPath('aclImdb/train/all/25309_0.txt'),
#   PosixPath('aclImdb/train/all/12160_0.txt'),
#   PosixPath('aclImdb/train/all/30079_0.txt'),
#   PosixPath('aclImdb/train/all/17706_0.txt'),
#   PosixPath('aclImdb/train/all/38780_0.txt'),
#   PosixPath('aclImdb/train/all/28296_0.txt'),
#   PosixPath('aclImdb/train/all/44707_0.txt'),
#   PosixPath('aclImdb/train/all/41161_0.txt'),
#   PosixPath('aclImdb/train/all/49698_0.txt'),
#   PosixPath('aclImdb/train/all/1767_8.txt'),
#   PosixPath('aclImdb/train/all/4101_8.txt'),
#   PosixPath('aclImdb/train/all/1072_10.txt'),
#   PosixPath('aclImdb/train/all/23029_0.txt'),
#   PosixPath('aclImdb/train/all/11426_0.txt'),
#   PosixPath('aclImdb/train/all/36359_0.txt'),
#   PosixPath('aclImdb/train/all/14240_0.txt'),
#   PosixPath('aclImdb/train/all/16975_0.txt'),
#   PosixPath('aclImdb/train/all/47241_0.txt'),
#   PosixPath('aclImdb/train/all/42427_0.txt'),
#   PosixPath('aclImdb/train/all/45974_0.txt'),
#   PosixPath('aclImdb/train/all/2221_8.txt'),
#   PosixPath('aclImdb/train/all/7447_8.txt'),
#   PosixPath('aclImdb/train/all/8047_9.txt'),
#   PosixPath('aclImdb/train/all/3928_7.txt'),
#   PosixPath('aclImdb/train/all/1640_10.txt'),
#   PosixPath('aclImdb/train/all/2919_10.txt'),
#   PosixPath('aclImdb/train/all/1942_2.txt'),
#   PosixPath('aclImdb/train/all/1111_10.txt'),
#   PosixPath('aclImdb/train/all/11881_9.txt'),
#   PosixPath('aclImdb/train/all/8156_4.txt'),
#   PosixPath('aclImdb/train/all/40751_0.txt'),
#   PosixPath('aclImdb/train/all/45137_0.txt'),
#   PosixPath('aclImdb/train/all/16136_0.txt'),
#   PosixPath('aclImdb/train/all/31649_0.txt'),
#   PosixPath('aclImdb/train/all/13750_0.txt'),
#   PosixPath('aclImdb/train/all/24539_0.txt'),
#   PosixPath('aclImdb/train/all/12005_10.txt'),
#   PosixPath('aclImdb/train/all/6832_10.txt'),
#   PosixPath('aclImdb/train/all/9976_7.txt'),
#   PosixPath('aclImdb/train/all/572_1.txt'),
#   PosixPath('aclImdb/train/all/29077_0.txt'),
#   PosixPath('aclImdb/train/all/39561_0.txt'),
#   PosixPath('aclImdb/train/all/13381_0.txt'),
#   PosixPath('aclImdb/train/all/31298_0.txt'),
#   PosixPath('aclImdb/train/all/8831_0.txt'),
#   PosixPath('aclImdb/train/all/5418_4.txt'),
#   PosixPath('aclImdb/train/all/48479_0.txt'),
#   PosixPath('aclImdb/train/all/40380_0.txt'),
#   PosixPath('aclImdb/train/all/2108_4.txt'),
#   PosixPath('aclImdb/train/all/47690_0.txt'),
#   PosixPath('aclImdb/train/all/14691_0.txt'),
#   PosixPath('aclImdb/train/all/29834_0.txt'),
#   PosixPath('aclImdb/train/all/36788_0.txt'),
#   PosixPath('aclImdb/train/all/8072_0.txt'),
#   PosixPath('aclImdb/train/all/9229_2.txt'),
#   PosixPath('aclImdb/train/all/7402_8.txt'),
#   PosixPath('aclImdb/train/all/10638_2.txt'),
#   PosixPath('aclImdb/train/all/2680_1.txt'),
#   PosixPath('aclImdb/train/all/34829_0.txt'),
#   PosixPath('aclImdb/train/all/16930_0.txt'),
#   PosixPath('aclImdb/train/all/14205_0.txt'),
#   PosixPath('aclImdb/train/all/11463_0.txt'),
#   PosixPath('aclImdb/train/all/5579_0.txt'),
#   PosixPath('aclImdb/train/all/8950_4.txt'),
#   PosixPath('aclImdb/train/all/45931_0.txt'),
#   PosixPath('aclImdb/train/all/42462_0.txt'),
#   PosixPath('aclImdb/train/all/47204_0.txt'),
#   PosixPath('aclImdb/train/all/8113_4.txt'),
#   PosixPath('aclImdb/train/all/45172_0.txt'),
#   PosixPath('aclImdb/train/all/40714_0.txt'),
#   PosixPath('aclImdb/train/all/13715_0.txt'),
#   PosixPath('aclImdb/train/all/16173_0.txt'),
#   PosixPath('aclImdb/train/all/2069_0.txt'),
#   PosixPath('aclImdb/train/all/5390_1.txt'),
#   PosixPath('aclImdb/train/all/1907_2.txt'),
#   PosixPath('aclImdb/train/all/6454_2.txt'),
#   PosixPath('aclImdb/train/all/5774_8.txt'),
#   PosixPath('aclImdb/train/all/8874_0.txt'),
#   PosixPath('aclImdb/train/all/29032_0.txt'),
#   PosixPath('aclImdb/train/all/39524_0.txt'),
#   PosixPath('aclImdb/train/all/5741_1.txt'),
#   PosixPath('aclImdb/train/all/11547_4.txt'),
#   PosixPath('aclImdb/train/all/6399_7.txt'),
#   PosixPath('aclImdb/train/all/9485_3.txt'),
#   PosixPath('aclImdb/train/all/2251_1.txt'),
#   PosixPath('aclImdb/train/all/7437_1.txt'),
#   PosixPath('aclImdb/train/all/8037_0.txt'),
#   PosixPath('aclImdb/train/all/29871_0.txt'),
#   PosixPath('aclImdb/train/all/30298_0.txt'),
#   PosixPath('aclImdb/train/all/12381_0.txt'),
#   PosixPath('aclImdb/train/all/9831_0.txt'),
#   PosixPath('aclImdb/train/all/28077_0.txt'),
#   PosixPath('aclImdb/train/all/38561_0.txt'),
#   PosixPath('aclImdb/train/all/4704_1.txt'),
#   PosixPath('aclImdb/train/all/1162_1.txt'),
#   PosixPath('aclImdb/train/all/10502_4.txt'),
#   PosixPath('aclImdb/train/all/41380_0.txt'),
#   PosixPath('aclImdb/train/all/49479_0.txt'),
#   PosixPath('aclImdb/train/all/72_7.txt'),
#   PosixPath('aclImdb/train/all/8976_7.txt'),
#   PosixPath('aclImdb/train/all/12105_10.txt'),
#   PosixPath('aclImdb/train/all/11445_3.txt'),
#   PosixPath('aclImdb/train/all/7629_3.txt'),
#   PosixPath('aclImdb/train/all/46690_0.txt'),
#   PosixPath('aclImdb/train/all/9072_0.txt'),
#   PosixPath('aclImdb/train/all/28834_0.txt'),
#   PosixPath('aclImdb/train/all/37788_0.txt'),
#   PosixPath('aclImdb/train/all/15691_0.txt'),
#   PosixPath('aclImdb/train/all/6447_8.txt'),
#   PosixPath('aclImdb/train/all/8852_3.txt'),
#   PosixPath('aclImdb/train/all/2819_10.txt'),
#   PosixPath('aclImdb/train/all/17975_0.txt'),
#   PosixPath('aclImdb/train/all/22029_0.txt'),
#   PosixPath('aclImdb/train/all/15240_0.txt'),
#   PosixPath('aclImdb/train/all/37359_0.txt'),
#   PosixPath('aclImdb/train/all/10426_0.txt'),
#   PosixPath('aclImdb/train/all/44974_0.txt'),
#   PosixPath('aclImdb/train/all/43427_0.txt'),
#   PosixPath('aclImdb/train/all/46241_0.txt'),
#   PosixPath('aclImdb/train/all/44137_0.txt'),
#   PosixPath('aclImdb/train/all/41751_0.txt'),
#   PosixPath('aclImdb/train/all/12750_0.txt'),
#   PosixPath('aclImdb/train/all/30649_0.txt'),
#   PosixPath('aclImdb/train/all/17136_0.txt'),
#   PosixPath('aclImdb/train/all/25539_0.txt'),
#   PosixPath('aclImdb/train/all/1011_10.txt'),
#   PosixPath('aclImdb/train/all/4731_8.txt'),
#   PosixPath('aclImdb/train/all/6890_8.txt'),
#   PosixPath('aclImdb/train/all/8933_7.txt'),
#   PosixPath('aclImdb/train/all/8485_3.txt'),
#   PosixPath('aclImdb/train/all/28032_0.txt'),
#   PosixPath('aclImdb/train/all/38524_0.txt'),
#   PosixPath('aclImdb/train/all/9874_0.txt'),
#   PosixPath('aclImdb/train/all/1964_1.txt'),
#   PosixPath('aclImdb/train/all/28871_0.txt'),
#   PosixPath('aclImdb/train/all/6437_1.txt'),
#   PosixPath('aclImdb/train/all/9037_0.txt'),
#   PosixPath('aclImdb/train/all/3251_1.txt'),
#   PosixPath('aclImdb/train/all/8170_7.txt'),
#   PosixPath('aclImdb/train/all/10463_0.txt'),
#   PosixPath('aclImdb/train/all/4579_0.txt'),
#   PosixPath('aclImdb/train/all/15205_0.txt'),
#   PosixPath('aclImdb/train/all/17930_0.txt'),
#   PosixPath('aclImdb/train/all/35829_0.txt'),
#   PosixPath('aclImdb/train/all/648_7.txt'),
#   PosixPath('aclImdb/train/all/46204_0.txt'),
#   PosixPath('aclImdb/train/all/43462_0.txt'),
#   PosixPath('aclImdb/train/all/44931_0.txt'),
#   PosixPath('aclImdb/train/all/3264_8.txt'),
#   PosixPath('aclImdb/train/all/6402_8.txt'),
#   PosixPath('aclImdb/train/all/9002_9.txt'),
#   PosixPath('aclImdb/train/all/11524_7.txt'),
#   PosixPath('aclImdb/train/all/5988_3.txt'),
#   PosixPath('aclImdb/train/all/1112_8.txt'),
#   PosixPath('aclImdb/train/all/9113_4.txt'),
#   PosixPath('aclImdb/train/all/41714_0.txt'),
#   PosixPath('aclImdb/train/all/44172_0.txt'),
#   PosixPath('aclImdb/train/all/17173_0.txt'),
#   PosixPath('aclImdb/train/all/3069_0.txt'),
#   PosixPath('aclImdb/train/all/12715_0.txt'),
#   PosixPath('aclImdb/train/all/10900_8.txt'),
#   PosixPath('aclImdb/train/all/3549_8.txt'),
#   PosixPath('aclImdb/train/all/11149_10.txt'),
#   PosixPath('aclImdb/train/all/5313_7.txt'),
#   PosixPath('aclImdb/train/all/7590_3.txt'),
#   PosixPath('aclImdb/train/all/30962_0.txt'),
#   PosixPath('aclImdb/train/all/6961_0.txt'),
#   PosixPath('aclImdb/train/all/4254_0.txt'),
#   PosixPath('aclImdb/train/all/37431_0.txt'),
#   PosixPath('aclImdb/train/all/1432_0.txt'),
#   PosixPath('aclImdb/train/all/15528_0.txt'),
#   PosixPath('aclImdb/train/all/32257_0.txt'),
#   PosixPath('aclImdb/train/all/27127_0.txt'),
#   PosixPath('aclImdb/train/all/22741_0.txt'),
#   PosixPath('aclImdb/train/all/165_7.txt'),
#   PosixPath('aclImdb/train/all/46529_0.txt'),
#   PosixPath('aclImdb/train/all/926_7.txt'),
#   PosixPath('aclImdb/train/all/41039_0.txt'),
#   PosixPath('aclImdb/train/all/8694_10.txt'),
#   PosixPath('aclImdb/train/all/20437_0.txt'),
#   PosixPath('aclImdb/train/all/490_3.txt'),
#   PosixPath('aclImdb/train/all/25251_0.txt'),
#   PosixPath('aclImdb/train/all/3744_0.txt'),
#   PosixPath('aclImdb/train/all/30121_0.txt'),
#   PosixPath('aclImdb/train/all/12038_0.txt'),
#   PosixPath('aclImdb/train/all/6122_0.txt'),
#   PosixPath('aclImdb/train/all/9522_1.txt'),
#   PosixPath('aclImdb/train/all/35747_0.txt'),
#   PosixPath('aclImdb/train/all/27964_0.txt'),
#   PosixPath('aclImdb/train/all/7379_2.txt'),
#   PosixPath('aclImdb/train/all/10143_8.txt'),
#   PosixPath('aclImdb/train/all/4059_8.txt'),
#   PosixPath('aclImdb/train/all/7065_7.txt'),
#   PosixPath('aclImdb/train/all/25680_0.txt'),
#   PosixPath('aclImdb/train/all/18825_0.txt'),
#   PosixPath('aclImdb/train/all/35396_0.txt'),
#   PosixPath('aclImdb/train/all/3395_0.txt'),
#   PosixPath('aclImdb/train/all/10176_1.txt'),
#   PosixPath('aclImdb/train/all/38209_0.txt'),
#   PosixPath('aclImdb/train/all/49311_0.txt'),
#   PosixPath('aclImdb/train/all/10592_8.txt'),
#   PosixPath('aclImdb/train/all/7141_3.txt'),
#   PosixPath('aclImdb/train/all/2727_3.txt'),
#   PosixPath('aclImdb/train/all/4261_9.txt'),
#   PosixPath('aclImdb/train/all/6006_4.txt'),
#   PosixPath('aclImdb/train/all/18066_0.txt'),
#   PosixPath('aclImdb/train/all/32686_0.txt'),
#   PosixPath('aclImdb/train/all/4685_0.txt'),
#   PosixPath('aclImdb/train/all/22390_0.txt'),
#   PosixPath('aclImdb/train/all/32212_0.txt'),
#   PosixPath('aclImdb/train/all/1477_0.txt'),
#   PosixPath('aclImdb/train/all/37474_0.txt'),
#   PosixPath('aclImdb/train/all/4211_0.txt'),
#   PosixPath('aclImdb/train/all/22704_0.txt'),
#   PosixPath('aclImdb/train/all/27162_0.txt'),
#   PosixPath('aclImdb/train/all/6924_0.txt'),
#   PosixPath('aclImdb/train/all/30927_0.txt'),
#   PosixPath('aclImdb/train/all/8372_10.txt'),
#   PosixPath('aclImdb/train/all/6490_10.txt'),
#   PosixPath('aclImdb/train/all/10106_8.txt'),
#   PosixPath('aclImdb/train/all/49785_0.txt'),
#   PosixPath('aclImdb/train/all/9114_10.txt'),
#   PosixPath('aclImdb/train/all/27921_0.txt'),
#   PosixPath('aclImdb/train/all/25214_0.txt'),
#   PosixPath('aclImdb/train/all/20472_0.txt'),
#   PosixPath('aclImdb/train/all/35702_0.txt'),
#   PosixPath('aclImdb/train/all/6167_0.txt'),
#   PosixPath('aclImdb/train/all/9567_1.txt'),
#   PosixPath('aclImdb/train/all/30164_0.txt'),
#   PosixPath('aclImdb/train/all/3701_0.txt'),
#   PosixPath('aclImdb/train/all/3734_9.txt'),
#   PosixPath('aclImdb/train/all/9552_8.txt'),
#   PosixPath('aclImdb/train/all/2297_7.txt'),
#   PosixPath('aclImdb/train/all/159_10.txt'),
#   PosixPath('aclImdb/train/all/10133_1.txt'),
#   PosixPath('aclImdb/train/all/18860_0.txt'),
#   PosixPath('aclImdb/train/all/4335_4.txt'),
#   PosixPath('aclImdb/train/all/49354_0.txt'),
#   PosixPath('aclImdb/train/all/18023_0.txt'),
#   PosixPath('aclImdb/train/all/3539_1.txt'),
#   PosixPath('aclImdb/train/all/12245_1.txt'),
#   PosixPath('aclImdb/train/all/847_3.txt'),
#   PosixPath('aclImdb/train/all/11581_2.txt'),
#   PosixPath('aclImdb/train/all/8517_8.txt'),
#   PosixPath('aclImdb/train/all/6902_3.txt'),
#   PosixPath('aclImdb/train/all/4237_3.txt'),
#   PosixPath('aclImdb/train/all/39209_0.txt'),
#   PosixPath('aclImdb/train/all/11176_1.txt'),
#   PosixPath('aclImdb/train/all/19825_0.txt'),
#   PosixPath('aclImdb/train/all/24680_0.txt'),
#   PosixPath('aclImdb/train/all/2395_0.txt'),
#   PosixPath('aclImdb/train/all/34396_0.txt'),
#   PosixPath('aclImdb/train/all/5370_4.txt'),
#   PosixPath('aclImdb/train/all/48311_0.txt'),
#   PosixPath('aclImdb/train/all/854_9.txt'),
#   PosixPath('aclImdb/train/all/7006_4.txt'),
#   PosixPath('aclImdb/train/all/5685_0.txt'),
#   PosixPath('aclImdb/train/all/33686_0.txt'),
#   PosixPath('aclImdb/train/all/23390_0.txt'),
#   PosixPath('aclImdb/train/all/19066_0.txt'),
#   PosixPath('aclImdb/train/all/2198_8.txt'),
#   PosixPath('aclImdb/train/all/33257_0.txt'),
#   PosixPath('aclImdb/train/all/14528_0.txt'),
#   PosixPath('aclImdb/train/all/36431_0.txt'),
#   PosixPath('aclImdb/train/all/5254_0.txt'),
#   PosixPath('aclImdb/train/all/23741_0.txt'),
#   PosixPath('aclImdb/train/all/26127_0.txt'),
#   PosixPath('aclImdb/train/all/7961_0.txt'),
#   PosixPath('aclImdb/train/all/31962_0.txt'),
#   PosixPath('aclImdb/train/all/47529_0.txt'),
#   PosixPath('aclImdb/train/all/2549_8.txt'),
#   PosixPath('aclImdb/train/all/11900_8.txt'),
#   PosixPath('aclImdb/train/all/10209_7.txt'),
#   PosixPath('aclImdb/train/all/6590_3.txt'),
#   PosixPath('aclImdb/train/all/1669_2.txt'),
#   PosixPath('aclImdb/train/all/861_0.txt'),
#   PosixPath('aclImdb/train/all/9779_3.txt'),
#   PosixPath('aclImdb/train/all/10956_2.txt'),
#   PosixPath('aclImdb/train/all/11718_10.txt'),
#   PosixPath('aclImdb/train/all/7541_10.txt'),
#   PosixPath('aclImdb/train/all/3603_7.txt'),
#   PosixPath('aclImdb/train/all/40039_0.txt'),
#   PosixPath('aclImdb/train/all/26964_0.txt'),
#   PosixPath('aclImdb/train/all/24251_0.txt'),
#   PosixPath('aclImdb/train/all/21437_0.txt'),
#   PosixPath('aclImdb/train/all/34747_0.txt'),
#   PosixPath('aclImdb/train/all/13038_0.txt'),
#   PosixPath('aclImdb/train/all/7122_0.txt'),
#   PosixPath('aclImdb/train/all/31121_0.txt'),
#   PosixPath('aclImdb/train/all/2744_0.txt'),
#   PosixPath('aclImdb/train/all/19860_0.txt'),
#   PosixPath('aclImdb/train/all/5335_4.txt'),
#   PosixPath('aclImdb/train/all/48354_0.txt'),
#   PosixPath('aclImdb/train/all/7152_9.txt'),
#   PosixPath('aclImdb/train/all/2734_9.txt'),
#   PosixPath('aclImdb/train/all/1414_3.txt'),
#   PosixPath('aclImdb/train/all/9504_2.txt'),
#   PosixPath('aclImdb/train/all/3762_3.txt'),
#   PosixPath('aclImdb/train/all/19023_0.txt'),
#   PosixPath('aclImdb/train/all/2539_1.txt'),
#   PosixPath('aclImdb/train/all/6863_7.txt'),
#   PosixPath('aclImdb/train/all/31927_0.txt'),
#   PosixPath('aclImdb/train/all/7924_0.txt'),
#   PosixPath('aclImdb/train/all/5211_0.txt'),
#   PosixPath('aclImdb/train/all/36474_0.txt'),
#   PosixPath('aclImdb/train/all/33212_0.txt'),
#   PosixPath('aclImdb/train/all/26162_0.txt'),
#   PosixPath('aclImdb/train/all/23704_0.txt'),
#   PosixPath('aclImdb/train/all/9014_10.txt'),
#   PosixPath('aclImdb/train/all/48785_0.txt'),
#   PosixPath('aclImdb/train/all/21472_0.txt'),
#   PosixPath('aclImdb/train/all/24214_0.txt'),
#   PosixPath('aclImdb/train/all/2701_0.txt'),
#   PosixPath('aclImdb/train/all/31164_0.txt'),
#   PosixPath('aclImdb/train/all/7167_0.txt'),
#   PosixPath('aclImdb/train/all/8567_1.txt'),
#   PosixPath('aclImdb/train/all/34702_0.txt'),
#   PosixPath('aclImdb/train/all/26921_0.txt'),
#   PosixPath('aclImdb/train/all/824_0.txt'),
#   PosixPath('aclImdb/train/all/10098_10.txt'),
#   PosixPath('aclImdb/train/all/6020_7.txt'),
#   PosixPath('aclImdb/train/all/5608_9.txt'),
#   PosixPath('aclImdb/train/all/7397_8.txt'),
#   PosixPath('aclImdb/train/all/9128_2.txt'),
#   PosixPath('aclImdb/train/all/7773_1.txt'),
#   PosixPath('aclImdb/train/all/8373_0.txt'),
#   PosixPath('aclImdb/train/all/14590_0.txt'),
#   PosixPath('aclImdb/train/all/36489_0.txt'),
#   PosixPath('aclImdb/train/all/47591_0.txt'),
#   PosixPath('aclImdb/train/all/2209_4.txt'),
#   PosixPath('aclImdb/train/all/40081_0.txt'),
#   PosixPath('aclImdb/train/all/48778_0.txt'),
#   PosixPath('aclImdb/train/all/2956_1.txt'),
#   PosixPath('aclImdb/train/all/13080_0.txt'),
#   PosixPath('aclImdb/train/all/31199_0.txt'),
#   PosixPath('aclImdb/train/all/5405_1.txt'),
#   PosixPath('aclImdb/train/all/39660_0.txt'),
#   PosixPath('aclImdb/train/all/29376_0.txt'),
#   PosixPath('aclImdb/train/all/10744_3.txt'),
#   PosixPath('aclImdb/train/all/673_1.txt'),
#   PosixPath('aclImdb/train/all/24638_0.txt'),
#   PosixPath('aclImdb/train/all/16237_0.txt'),
#   PosixPath('aclImdb/train/all/31548_0.txt'),
#   PosixPath('aclImdb/train/all/13451_0.txt'),
#   PosixPath('aclImdb/train/all/14902_0.txt'),
#   PosixPath('aclImdb/train/all/40450_0.txt'),
#   PosixPath('aclImdb/train/all/45236_0.txt'),
#   PosixPath('aclImdb/train/all/47903_0.txt'),
#   PosixPath('aclImdb/train/all/2963_8.txt'),
#   PosixPath('aclImdb/train/all/4466_2.txt'),
#   PosixPath('aclImdb/train/all/4570_10.txt'),
#   PosixPath('aclImdb/train/all/11870_10.txt'),
#   PosixPath('aclImdb/train/all/2120_8.txt'),
#   PosixPath('aclImdb/train/all/8346_9.txt'),
#   PosixPath('aclImdb/train/all/47140_0.txt'),
#   PosixPath('aclImdb/train/all/42726_0.txt'),
#   PosixPath('aclImdb/train/all/11727_0.txt'),
#   PosixPath('aclImdb/train/all/36058_0.txt'),
#   PosixPath('aclImdb/train/all/14141_0.txt'),
#   PosixPath('aclImdb/train/all/5897_1.txt'),
#   PosixPath('aclImdb/train/all/23328_0.txt'),
#   PosixPath('aclImdb/train/all/13886_0.txt'),
#   PosixPath('aclImdb/train/all/8336_0.txt'),
#   PosixPath('aclImdb/train/all/40887_0.txt'),
#   PosixPath('aclImdb/train/all/11757_9.txt'),
#   PosixPath('aclImdb/train/all/6384_2.txt'),
#   PosixPath('aclImdb/train/all/9784_3.txt'),
#   PosixPath('aclImdb/train/all/11646_4.txt'),
#   PosixPath('aclImdb/train/all/39625_0.txt'),
#   PosixPath('aclImdb/train/all/26999_0.txt'),
#   PosixPath('aclImdb/train/all/29333_0.txt'),
#   PosixPath('aclImdb/train/all/4096_10.txt'),
#   PosixPath('aclImdb/train/all/2926_8.txt'),
#   PosixPath('aclImdb/train/all/5475_8.txt'),
#   PosixPath('aclImdb/train/all/5091_1.txt'),
#   PosixPath('aclImdb/train/all/14947_0.txt'),
#   PosixPath('aclImdb/train/all/13414_0.txt'),
#   PosixPath('aclImdb/train/all/16272_0.txt'),
#   PosixPath('aclImdb/train/all/2368_0.txt'),
#   PosixPath('aclImdb/train/all/47946_0.txt'),
#   PosixPath('aclImdb/train/all/45273_0.txt'),
#   PosixPath('aclImdb/train/all/40415_0.txt'),
#   PosixPath('aclImdb/train/all/42763_0.txt'),
#   PosixPath('aclImdb/train/all/47105_0.txt'),
#   PosixPath('aclImdb/train/all/14104_0.txt'),
#   PosixPath('aclImdb/train/all/11762_0.txt'),
#   PosixPath('aclImdb/train/all/5678_0.txt'),
#   PosixPath('aclImdb/train/all/21858_0.txt'),
#   PosixPath('aclImdb/train/all/2581_1.txt'),
#   PosixPath('aclImdb/train/all/3970_2.txt'),
#   PosixPath('aclImdb/train/all/1245_2.txt'),
#   PosixPath('aclImdb/train/all/4423_2.txt'),
#   PosixPath('aclImdb/train/all/10625_7.txt'),
#   PosixPath('aclImdb/train/all/7703_8.txt'),
#   PosixPath('aclImdb/train/all/1256_8.txt'),
#   PosixPath('aclImdb/train/all/4430_8.txt'),
#   PosixPath('aclImdb/train/all/15902_0.txt'),
#   PosixPath('aclImdb/train/all/1818_0.txt'),
#   PosixPath('aclImdb/train/all/25638_0.txt'),
#   PosixPath('aclImdb/train/all/12451_0.txt'),
#   PosixPath('aclImdb/train/all/30548_0.txt'),
#   PosixPath('aclImdb/train/all/17237_0.txt'),
#   PosixPath('aclImdb/train/all/46903_0.txt'),
#   PosixPath('aclImdb/train/all/44236_0.txt'),
#   PosixPath('aclImdb/train/all/41450_0.txt'),
#   PosixPath('aclImdb/train/all/9257_4.txt'),
#   PosixPath('aclImdb/train/all/43726_0.txt'),
#   PosixPath('aclImdb/train/all/46140_0.txt'),
#   PosixPath('aclImdb/train/all/15141_0.txt'),
#   PosixPath('aclImdb/train/all/37058_0.txt'),
#   PosixPath('aclImdb/train/all/10727_0.txt'),
#   PosixPath('aclImdb/train/all/22328_0.txt'),
#   PosixPath('aclImdb/train/all/2935_2.txt'),
#   PosixPath('aclImdb/train/all/11660_7.txt'),
#   PosixPath('aclImdb/train/all/11970_10.txt'),
#   PosixPath('aclImdb/train/all/6746_8.txt'),
#   PosixPath('aclImdb/train/all/3120_8.txt'),
#   PosixPath('aclImdb/train/all/37489_0.txt'),
#   PosixPath('aclImdb/train/all/15590_0.txt'),
#   PosixPath('aclImdb/train/all/9373_0.txt'),
#   PosixPath('aclImdb/train/all/46591_0.txt'),
#   PosixPath('aclImdb/train/all/8234_7.txt'),
#   PosixPath('aclImdb/train/all/6397_8.txt'),
#   PosixPath('aclImdb/train/all/4608_9.txt'),
#   PosixPath('aclImdb/train/all/3318_9.txt'),
#   PosixPath('aclImdb/train/all/49778_0.txt'),
#   PosixPath('aclImdb/train/all/41081_0.txt'),
#   PosixPath('aclImdb/train/all/38660_0.txt'),
#   PosixPath('aclImdb/train/all/28376_0.txt'),
#   PosixPath('aclImdb/train/all/3956_1.txt'),
#   PosixPath('aclImdb/train/all/30199_0.txt'),
#   PosixPath('aclImdb/train/all/12080_0.txt'),
#   PosixPath('aclImdb/train/all/17272_0.txt'),
#   PosixPath('aclImdb/train/all/3368_0.txt'),
#   PosixPath('aclImdb/train/all/12414_0.txt'),
#   PosixPath('aclImdb/train/all/4091_1.txt'),
#   PosixPath('aclImdb/train/all/15947_0.txt'),
#   PosixPath('aclImdb/train/all/41415_0.txt'),
#   PosixPath('aclImdb/train/all/44273_0.txt'),
#   PosixPath('aclImdb/train/all/46946_0.txt'),
#   PosixPath('aclImdb/train/all/4475_8.txt'),
#   PosixPath('aclImdb/train/all/11625_7.txt'),
#   PosixPath('aclImdb/train/all/6703_8.txt'),
#   PosixPath('aclImdb/train/all/46105_0.txt'),
#   ...],
#  [PosixPath('aclImdb/test/all/4715_9.txt'),
#   PosixPath('aclImdb/test/all/1821_4.txt'),
#   PosixPath('aclImdb/test/all/9487_1.txt'),
#   PosixPath('aclImdb/test/all/4604_4.txt'),
#   PosixPath('aclImdb/test/all/1930_9.txt'),
#   PosixPath('aclImdb/test/all/3205_9.txt'),
#   PosixPath('aclImdb/test/all/10186_10.txt'),
#   PosixPath('aclImdb/test/all/147_10.txt'),
#   PosixPath('aclImdb/test/all/7511_7.txt'),
#   PosixPath('aclImdb/test/all/2828_2.txt'),
#   PosixPath('aclImdb/test/all/616_10.txt'),
#   PosixPath('aclImdb/test/all/10890_1.txt'),
#   PosixPath('aclImdb/test/all/3351_4.txt'),
#   PosixPath('aclImdb/test/all/8070_2.txt'),
#   PosixPath('aclImdb/test/all/10460_10.txt'),
#   PosixPath('aclImdb/test/all/3240_9.txt'),
#   PosixPath('aclImdb/test/all/1975_9.txt'),
#   PosixPath('aclImdb/test/all/1027_4.txt'),
#   PosixPath('aclImdb/test/all/8248_3.txt'),
#   PosixPath('aclImdb/test/all/3225_10.txt'),
#   PosixPath('aclImdb/test/all/4290_4.txt'),
#   PosixPath('aclImdb/test/all/10096_1.txt'),
#   PosixPath('aclImdb/test/all/4381_9.txt'),
#   PosixPath('aclImdb/test/all/6511_7.txt'),
#   PosixPath('aclImdb/test/all/11890_1.txt'),
#   PosixPath('aclImdb/test/all/4667_7.txt'),
#   PosixPath('aclImdb/test/all/716_10.txt'),
#   PosixPath('aclImdb/test/all/2008_1.txt'),
#   PosixPath('aclImdb/test/all/6983_7.txt'),
#   PosixPath('aclImdb/test/all/7463_9.txt'),
#   PosixPath('aclImdb/test/all/10086_10.txt'),
#   PosixPath('aclImdb/test/all/472_4.txt'),
#   PosixPath('aclImdb/test/all/9876_2.txt'),
#   PosixPath('aclImdb/test/all/11402_1.txt'),
#   PosixPath('aclImdb/test/all/8487_1.txt'),
#   PosixPath('aclImdb/test/all/6648_2.txt'),
#   PosixPath('aclImdb/test/all/2612_10.txt'),
#   PosixPath('aclImdb/test/all/3325_10.txt'),
#   PosixPath('aclImdb/test/all/5568_8.txt'),
#   PosixPath('aclImdb/test/all/1807_7.txt'),
#   PosixPath('aclImdb/test/all/3474_10.txt'),
#   PosixPath('aclImdb/test/all/2780_4.txt'),
#   PosixPath('aclImdb/test/all/1789_2.txt'),
#   PosixPath('aclImdb/test/all/2351_4.txt'),
#   PosixPath('aclImdb/test/all/11447_1.txt'),
#   PosixPath('aclImdb/test/all/6068_10.txt'),
#   PosixPath('aclImdb/test/all/12383_2.txt'),
#   PosixPath('aclImdb/test/all/2760_1.txt'),
#   PosixPath('aclImdb/test/all/2384_8.txt'),
#   PosixPath('aclImdb/test/all/10131_3.txt'),
#   PosixPath('aclImdb/test/all/803_10.txt'),
#   PosixPath('aclImdb/test/all/5270_1.txt'),
#   PosixPath('aclImdb/test/all/6165_2.txt'),
# ...
#   PosixPath('aclImdb/test/all/3391_4.txt'),
#   PosixPath('aclImdb/test/all/6126_4.txt'),
#   PosixPath('aclImdb/test/all/9890_1.txt'),
#   PosixPath('aclImdb/test/all/12320_1.txt'),
#   PosixPath('aclImdb/test/all/922_3.txt'),
#   PosixPath('aclImdb/test/all/10056_1.txt'),
#   PosixPath('aclImdb/test/all/161_3.txt'),
#   PosixPath('aclImdb/test/all/4250_4.txt'),
#   PosixPath('aclImdb/test/all/7688_2.txt'),
#   PosixPath('aclImdb/test/all/1847_10.txt'),
#   PosixPath('aclImdb/test/all/4184_10.txt'),
#   PosixPath('aclImdb/test/all/3806_8.txt'),
#   PosixPath('aclImdb/test/all/4560_1.txt'),
#   PosixPath('aclImdb/test/all/1306_1.txt'),
#   PosixPath('aclImdb/test/all/5991_2.txt'),
#   PosixPath('aclImdb/test/all/11621_3.txt'),
#   PosixPath('aclImdb/test/all/8351_7.txt'),
#   PosixPath('aclImdb/test/all/1598_10.txt'),
#   PosixPath('aclImdb/test/all/3070_1.txt'),
#   PosixPath('aclImdb/test/all/12084_4.txt'),
#   PosixPath('aclImdb/test/all/12398_1.txt'),
#   PosixPath('aclImdb/test/all/6282_1.txt'),
#   PosixPath('aclImdb/test/all/11740_7.txt'),
#   PosixPath('aclImdb/test/all/3000_8.txt'),
#   PosixPath('aclImdb/test/all/6666_8.txt'),
#   PosixPath('aclImdb/test/all/1376_8.txt'),
#   PosixPath('aclImdb/test/all/8230_3.txt'),
#   PosixPath('aclImdb/test/all/2487_2.txt'),
#   PosixPath('aclImdb/test/all/10723_4.txt'),
#   PosixPath('aclImdb/test/all/3876_1.txt'),
#   PosixPath('aclImdb/test/all/4525_1.txt'),
#   PosixPath('aclImdb/test/all/3035_1.txt'),
#   PosixPath('aclImdb/test/all/3329_4.txt'),
#   PosixPath('aclImdb/test/all/8314_7.txt'),
#   PosixPath('aclImdb/test/all/10632_9.txt'),
#   PosixPath('aclImdb/test/all/7408_3.txt'),
#   PosixPath('aclImdb/test/all/5184_8.txt'),
#   PosixPath('aclImdb/test/all/9351_7.txt'),
#   PosixPath('aclImdb/test/all/2494_8.txt'),
#   PosixPath('aclImdb/test/all/8858_8.txt'),
#   PosixPath('aclImdb/test/all/1498_10.txt'),
#   PosixPath('aclImdb/test/all/7623_8.txt'),
#   PosixPath('aclImdb/test/all/9275_3.txt'),
#   PosixPath('aclImdb/test/all/7998_4.txt'),
#   PosixPath('aclImdb/test/all/11723_4.txt'),
#   PosixPath('aclImdb/test/all/5525_1.txt'),
#   PosixPath('aclImdb/test/all/2876_1.txt'),
#   PosixPath('aclImdb/test/all/3487_2.txt'),
#   PosixPath('aclImdb/test/all/2976_10.txt'),
#   PosixPath('aclImdb/test/all/9008_2.txt'),
#   PosixPath('aclImdb/test/all/3815_2.txt'),
#   PosixPath('aclImdb/test/all/5055_10.txt'),
#   PosixPath('aclImdb/test/all/7666_8.txt'),
#   PosixPath('aclImdb/test/all/766_8.txt'),
#   PosixPath('aclImdb/test/all/9230_3.txt'),
#   PosixPath('aclImdb/test/all/3467_7.txt'),
#   PosixPath('aclImdb/test/all/4934_7.txt'),
#   PosixPath('aclImdb/test/all/11327_8.txt'),
#   PosixPath('aclImdb/test/all/4482_3.txt'),
#   PosixPath('aclImdb/test/all/12007_2.txt'),
#   PosixPath('aclImdb/test/all/77_10.txt'),
#   PosixPath('aclImdb/test/all/7799_10.txt'),
#   PosixPath('aclImdb/test/all/8773_8.txt'),
#   PosixPath('aclImdb/test/all/8397_1.txt'),
#   PosixPath('aclImdb/test/all/11312_1.txt'),
#   PosixPath('aclImdb/test/all/2718_1.txt'),
#   PosixPath('aclImdb/test/all/2404_4.txt'),
#   PosixPath('aclImdb/test/all/7262_4.txt'),
#   PosixPath('aclImdb/test/all/11291_10.txt'),
#   PosixPath('aclImdb/test/all/4810_3.txt'),
#   PosixPath('aclImdb/test/all/3543_3.txt'),
#   PosixPath('aclImdb/test/all/6325_3.txt'),
#   PosixPath('aclImdb/test/all/3405_10.txt'),
#   PosixPath('aclImdb/test/all/1448_2.txt'),
#   PosixPath('aclImdb/test/all/4132_7.txt'),
#   PosixPath('aclImdb/test/all/8703_1.txt'),
#   PosixPath('aclImdb/test/all/5278_8.txt'),
#   PosixPath('aclImdb/test/all/2663_10.txt'),
#   PosixPath('aclImdb/test/all/6158_2.txt'),
#   PosixPath('aclImdb/test/all/9558_3.txt'),
#   PosixPath('aclImdb/test/all/5151_4.txt'),
#   PosixPath('aclImdb/test/all/11357_1.txt'),
#   PosixPath('aclImdb/test/all/6589_2.txt'),
#   PosixPath('aclImdb/test/all/10240_10.txt'),
#   PosixPath('aclImdb/test/all/6019_10.txt'),
#   PosixPath('aclImdb/test/all/6695_7.txt'),
#   PosixPath('aclImdb/test/all/98_9.txt'),
#   PosixPath('aclImdb/test/all/8736_8.txt'),
#   PosixPath('aclImdb/test/all/5803_9.txt'),
#   PosixPath('aclImdb/test/all/1385_7.txt'),
#   PosixPath('aclImdb/test/all/10511_10.txt'),
#   PosixPath('aclImdb/test/all/9760_2.txt'),
#   PosixPath('aclImdb/test/all/1099_2.txt'),
#   PosixPath('aclImdb/test/all/7227_4.txt'),
#   PosixPath('aclImdb/test/all/2441_4.txt'),
#   PosixPath('aclImdb/test/all/5912_4.txt'),
#   PosixPath('aclImdb/test/all/10312_1.txt'),
#   PosixPath('aclImdb/test/all/9397_1.txt'),
#   PosixPath('aclImdb/test/all/225_3.txt'),
#   PosixPath('aclImdb/test/all/11149_3.txt'),
#   PosixPath('aclImdb/test/all/12269_9.txt'),
#   PosixPath('aclImdb/test/all/11391_10.txt'),
#   PosixPath('aclImdb/test/all/8439_7.txt'),
#   PosixPath('aclImdb/test/all/12480_8.txt'),
#   PosixPath('aclImdb/test/all/1663_9.txt'),
#   PosixPath('aclImdb/test/all/2543_3.txt'),
#   PosixPath('aclImdb/test/all/12064_1.txt'),
#   PosixPath('aclImdb/test/all/3718_1.txt'),
#   PosixPath('aclImdb/test/all/6262_4.txt'),
#   PosixPath('aclImdb/test/all/667_10.txt'),
#   PosixPath('aclImdb/test/all/9746_1.txt'),
#   PosixPath('aclImdb/test/all/6119_10.txt'),
#   PosixPath('aclImdb/test/all/11677_10.txt'),
#   PosixPath('aclImdb/test/all/6978_1.txt'),
#   PosixPath('aclImdb/test/all/12021_1.txt'),
#   PosixPath('aclImdb/test/all/6227_4.txt'),
#   PosixPath('aclImdb/test/all/10411_10.txt'),
#   PosixPath('aclImdb/test/all/11334_2.txt'),
#   PosixPath('aclImdb/test/all/3768_8.txt'),
#   PosixPath('aclImdb/test/all/2422_7.txt'),
#   PosixPath('aclImdb/test/all/381_10.txt'),
#   PosixPath('aclImdb/test/all/9703_1.txt'),
#   PosixPath('aclImdb/test/all/5482_2.txt'),
#   PosixPath('aclImdb/test/all/6908_9.txt'),
#   PosixPath('aclImdb/test/all/6346_1.txt'),
#   PosixPath('aclImdb/test/all/10969_1.txt'),
#   PosixPath('aclImdb/test/all/10236_4.txt'),
#   PosixPath('aclImdb/test/all/3987_8.txt'),
#   PosixPath('aclImdb/test/all/927_10.txt'),
#   PosixPath('aclImdb/test/all/11371_3.txt'),
#   PosixPath('aclImdb/test/all/1287_1.txt'),
#   PosixPath('aclImdb/test/all/4846_8.txt'),
#   PosixPath('aclImdb/test/all/3515_8.txt'),
#   PosixPath('aclImdb/test/all/4836_1.txt'),
#   PosixPath('aclImdb/test/all/12219_1.txt'),
#   PosixPath('aclImdb/test/all/2823_10.txt'),
#   PosixPath('aclImdb/test/all/4278_9.txt'),
#   PosixPath('aclImdb/test/all/5651_10.txt'),
#   PosixPath('aclImdb/test/all/4366_10.txt'),
#   PosixPath('aclImdb/test/all/5100_10.txt'),
#   PosixPath('aclImdb/test/all/5016_2.txt'),
#   PosixPath('aclImdb/test/all/12123_7.txt'),
#   PosixPath('aclImdb/test/all/5005_8.txt'),
#   PosixPath('aclImdb/test/all/8662_4.txt'),
#   PosixPath('aclImdb/test/all/7797_1.txt'),
#   PosixPath('aclImdb/test/all/4780_10.txt'),
#   PosixPath('aclImdb/test/all/2515_8.txt'),
#   PosixPath('aclImdb/test/all/4053_2.txt'),
#   PosixPath('aclImdb/test/all/10684_7.txt'),
#   PosixPath('aclImdb/test/all/919_4.txt'),
#   PosixPath('aclImdb/test/all/2987_8.txt'),
#   PosixPath('aclImdb/test/all/3192_2.txt'),
#   PosixPath('aclImdb/test/all/4855_2.txt'),
#   PosixPath('aclImdb/test/all/5751_10.txt'),
#   PosixPath('aclImdb/test/all/4266_10.txt'),
#   PosixPath('aclImdb/test/all/5040_8.txt'),
#   PosixPath('aclImdb/test/all/4537_10.txt'),
#   PosixPath('aclImdb/test/all/10210_7.txt'),
#   PosixPath('aclImdb/test/all/5000_10.txt'),
#   PosixPath('aclImdb/test/all/9189_2.txt'),
#   PosixPath('aclImdb/test/all/7303_1.txt'),
#   PosixPath('aclImdb/test/all/2565_1.txt'),
#   PosixPath('aclImdb/test/all/11273_4.txt'),
#   PosixPath('aclImdb/test/all/2248_1.txt'),
#   PosixPath('aclImdb/test/all/6675_3.txt'),
#   PosixPath('aclImdb/test/all/2806_9.txt'),
#   PosixPath('aclImdb/test/all/4895_10.txt'),
#   PosixPath('aclImdb/test/all/11642_1.txt'),
#   PosixPath('aclImdb/test/all/2481_10.txt'),
#   PosixPath('aclImdb/test/all/4427_7.txt'),
#   PosixPath('aclImdb/test/all/1241_7.txt'),
#   PosixPath('aclImdb/test/all/3974_7.txt'),
#   PosixPath('aclImdb/test/all/10621_2.txt'),
#   PosixPath('aclImdb/test/all/4991_3.txt'),
#   PosixPath('aclImdb/test/all/3056_3.txt'),
#   PosixPath('aclImdb/test/all/10544_10.txt'),
#   PosixPath('aclImdb/test/all/5510_9.txt'),
#   PosixPath('aclImdb/test/all/8682_1.txt'),
#   PosixPath('aclImdb/test/all/10215_10.txt'),
#   PosixPath('aclImdb/test/all/2000_9.txt'),
#   PosixPath('aclImdb/test/all/4546_3.txt'),
#   PosixPath('aclImdb/test/all/8253_1.txt'),
#   PosixPath('aclImdb/test/all/6408_2.txt'),
#   PosixPath('aclImdb/test/all/6714_7.txt'),
#   PosixPath('aclImdb/test/all/11898_9.txt'),
#   PosixPath('aclImdb/test/all/5982_9.txt'),
#   PosixPath('aclImdb/test/all/4462_7.txt'),
#   PosixPath('aclImdb/test/all/585_10.txt'),
#   PosixPath('aclImdb/test/all/9216_1.txt'),
#   PosixPath('aclImdb/test/all/10293_1.txt'),
#   PosixPath('aclImdb/test/all/3494_9.txt'),
#   PosixPath('aclImdb/test/all/2974_7.txt'),
#   PosixPath('aclImdb/test/all/7675_3.txt'),
#   PosixPath('aclImdb/test/all/8275_2.txt'),
#   PosixPath('aclImdb/test/all/4555_9.txt'),
#   PosixPath('aclImdb/test/all/10642_1.txt'),
#   PosixPath('aclImdb/test/all/8419_10.txt'),
#   PosixPath('aclImdb/test/all/3045_9.txt'),
#   PosixPath('aclImdb/test/all/9223_8.txt'),
#   PosixPath('aclImdb/test/all/3238_8.txt'),
#   PosixPath('aclImdb/test/all/485_10.txt'),
#   PosixPath('aclImdb/test/all/11173_10.txt'),
#   PosixPath('aclImdb/test/all/11622_10.txt'),
#   PosixPath('aclImdb/test/all/10315_10.txt'),
#   PosixPath('aclImdb/test/all/9266_8.txt'),
#   PosixPath('aclImdb/test/all/10607_1.txt'),
#   PosixPath('aclImdb/test/all/9682_1.txt'),
#   PosixPath('aclImdb/test/all/9399_10.txt'),
#   PosixPath('aclImdb/test/all/124_2.txt'),
#   PosixPath('aclImdb/test/all/7867_2.txt'),
#   PosixPath('aclImdb/test/all/11154_7.txt'),
#   PosixPath('aclImdb/test/all/6831_8.txt'),
#   PosixPath('aclImdb/test/all/4304_8.txt'),
#   PosixPath('aclImdb/test/all/1562_8.txt'),
#   PosixPath('aclImdb/test/all/1186_1.txt'),
#   PosixPath('aclImdb/test/all/967_2.txt'),
#   PosixPath('aclImdb/test/all/9917_10.txt'),
#   PosixPath('aclImdb/test/all/4331_1.txt'),
#   PosixPath('aclImdb/test/all/6804_1.txt'),
#   PosixPath('aclImdb/test/all/11585_7.txt'),
#   PosixPath('aclImdb/test/all/11699_2.txt'),
#   PosixPath('aclImdb/test/all/11952_7.txt'),
#   PosixPath('aclImdb/test/all/5848_7.txt'),
#   PosixPath('aclImdb/test/all/7061_2.txt'),
#   PosixPath('aclImdb/test/all/6841_1.txt'),
#   PosixPath('aclImdb/test/all/1512_1.txt'),
#   PosixPath('aclImdb/test/all/4179_9.txt'),
#   PosixPath('aclImdb/test/all/12118_1.txt'),
#   PosixPath('aclImdb/test/all/10070_3.txt'),
#   PosixPath('aclImdb/test/all/11026_9.txt'),
#   PosixPath('aclImdb/test/all/9500_7.txt'),
#   PosixPath('aclImdb/test/all/7072_8.txt'),
#   PosixPath('aclImdb/test/all/7496_1.txt'),
#   PosixPath('aclImdb/test/all/7831_8.txt'),
#   PosixPath('aclImdb/test/all/12222_7.txt'),
#   PosixPath('aclImdb/test/all/6338_7.txt'),
#   PosixPath('aclImdb/test/all/596_1.txt'),
#   PosixPath('aclImdb/test/all/5374_1.txt'),
#   PosixPath('aclImdb/test/all/7874_8.txt'),
#   PosixPath('aclImdb/test/all/10520_2.txt'),
#   PosixPath('aclImdb/test/all/2684_4.txt'),
#   PosixPath('aclImdb/test/all/8954_1.txt'),
#   PosixPath('aclImdb/test/all/2598_1.txt'),
#   PosixPath('aclImdb/test/all/11192_1.txt'),
#   PosixPath('aclImdb/test/all/5088_1.txt'),
#   PosixPath('aclImdb/test/all/9053_10.txt'),
#   PosixPath('aclImdb/test/all/8564_10.txt'),
#   PosixPath('aclImdb/test/all/6286_10.txt'),
#   PosixPath('aclImdb/test/all/5745_4.txt'),
#   PosixPath('aclImdb/test/all/5459_1.txt'),
#   PosixPath('aclImdb/test/all/1827_3.txt'),
#   PosixPath('aclImdb/test/all/6574_3.txt'),
#   PosixPath('aclImdb/test/all/3312_3.txt'),
#   PosixPath('aclImdb/test/all/8911_1.txt'),
#   PosixPath('aclImdb/test/all/4763_7.txt'),
#   PosixPath('aclImdb/test/all/5429_8.txt'),
#   PosixPath('aclImdb/test/all/1946_7.txt'),
#   PosixPath('aclImdb/test/all/4296_3.txt'),
#   PosixPath('aclImdb/test/all/8152_1.txt'),
#   PosixPath('aclImdb/test/all/7567_9.txt'),
#   PosixPath('aclImdb/test/all/576_4.txt'),
#   PosixPath('aclImdb/test/all/2210_4.txt'),
#   PosixPath('aclImdb/test/all/7476_4.txt'),
#   PosixPath('aclImdb/test/all/467_9.txt'),
#   PosixPath('aclImdb/test/all/5611_9.txt'),
#   PosixPath('aclImdb/test/all/9122_8.txt'),
#   PosixPath('aclImdb/test/all/3149_1.txt'),
#   PosixPath('aclImdb/test/all/2312_3.txt'),
#   PosixPath('aclImdb/test/all/7574_3.txt'),
#   PosixPath('aclImdb/test/all/2969_2.txt'),
#   PosixPath('aclImdb/test/all/3795_9.txt'),
#   PosixPath('aclImdb/test/all/2236_7.txt'),
#   PosixPath('aclImdb/test/all/10192_1.txt'),
#   PosixPath('aclImdb/test/all/987_7.txt'),
#   PosixPath('aclImdb/test/all/10506_1.txt'),
#   PosixPath('aclImdb/test/all/8972_2.txt'),
#   PosixPath('aclImdb/test/all/1834_9.txt'),
#   PosixPath('aclImdb/test/all/9167_8.txt'),
#   PosixPath('aclImdb/test/all/9924_8.txt'),
#   PosixPath('aclImdb/test/all/7887_7.txt'),
#   PosixPath('aclImdb/test/all/7357_10.txt'),
#   PosixPath('aclImdb/test/all/8182_10.txt'),
#   PosixPath('aclImdb/test/all/9911_1.txt'),
#   PosixPath('aclImdb/test/all/7709_2.txt'),
#   PosixPath('aclImdb/test/all/7697_4.txt'),
#   PosixPath('aclImdb/test/all/7234_10.txt'),
#   PosixPath('aclImdb/test/all/6139_2.txt'),
#   PosixPath('aclImdb/test/all/6052_10.txt'),
#   PosixPath('aclImdb/test/all/7565_10.txt'),
#   PosixPath('aclImdb/test/all/11303_8.txt'),
#   PosixPath('aclImdb/test/all/9287_10.txt'),
#   PosixPath('aclImdb/test/all/2531_9.txt'),
#   PosixPath('aclImdb/test/all/2628_10.txt'),
#   PosixPath('aclImdb/test/all/257_9.txt'),
#   PosixPath('aclImdb/test/all/819_1.txt'),
#   PosixPath('aclImdb/test/all/4582_7.txt'),
#   PosixPath('aclImdb/test/all/4116_7.txt'),
#   PosixPath('aclImdb/test/all/9395_2.txt'),
#   PosixPath('aclImdb/test/all/8256_10.txt'),
#   PosixPath('aclImdb/test/all/8727_1.txt'),
#   PosixPath('aclImdb/test/all/4955_7.txt'),
#   PosixPath('aclImdb/test/all/11346_8.txt'),
#   PosixPath('aclImdb/test/all/5269_1.txt'),
#   PosixPath('aclImdb/test/all/10336_1.txt'),
#   PosixPath('aclImdb/test/all/4862_9.txt'),
#   PosixPath('aclImdb/test/all/3531_9.txt'),
#   PosixPath('aclImdb/test/all/1871_10.txt'),
#   PosixPath('aclImdb/test/all/5077_3.txt'),
#   PosixPath('aclImdb/test/all/2079_10.txt'),
#   PosixPath('aclImdb/test/all/4973_4.txt'),
#   PosixPath('aclImdb/test/all/6246_4.txt'),
#   PosixPath('aclImdb/test/all/3420_4.txt'),
#   PosixPath('aclImdb/test/all/12040_1.txt'),
#   PosixPath('aclImdb/test/all/7334_10.txt'),
#   PosixPath('aclImdb/test/all/6603_10.txt'),
#   PosixPath('aclImdb/test/all/11355_2.txt'),
#   PosixPath('aclImdb/test/all/6697_4.txt'),
#   PosixPath('aclImdb/test/all/5910_7.txt'),
#   PosixPath('aclImdb/test/all/3574_9.txt'),
#   PosixPath('aclImdb/test/all/12208_9.txt'),
#   PosixPath('aclImdb/test/all/6312_9.txt'),
#   PosixPath('aclImdb/test/all/4269_1.txt'),
#   PosixPath('aclImdb/test/all/3779_1.txt'),
#   PosixPath('aclImdb/test/all/2522_3.txt'),
#   PosixPath('aclImdb/test/all/8744_2.txt'),
#   PosixPath('aclImdb/test/all/9661_10.txt'),
#   PosixPath('aclImdb/test/all/7183_10.txt'),
#   PosixPath('aclImdb/test/all/12030_8.txt'),
#   PosixPath('aclImdb/test/all/7260_7.txt'),
#   PosixPath('aclImdb/test/all/8407_10.txt'),
#   PosixPath('aclImdb/test/all/3061_8.txt'),
#   PosixPath('aclImdb/test/all/2874_2.txt'),
#   PosixPath('aclImdb/test/all/9849_1.txt'),
#   PosixPath('aclImdb/test/all/3485_1.txt'),
#   PosixPath('aclImdb/test/all/9316_4.txt'),
#   PosixPath('aclImdb/test/all/4195_1.txt'),
#   PosixPath('aclImdb/test/all/2037_2.txt'),
#   PosixPath('aclImdb/test/all/3822_8.txt'),
#   PosixPath('aclImdb/test/all/3817_1.txt'),
#   PosixPath('aclImdb/test/all/1322_1.txt'),
#   PosixPath('aclImdb/test/all/4658_4.txt'),
#   PosixPath('aclImdb/test/all/11929_10.txt'),
#   PosixPath('aclImdb/test/all/380_2.txt'),
#   PosixPath('aclImdb/test/all/3054_1.txt'),
#   PosixPath('aclImdb/test/all/6632_1.txt'),
#   PosixPath('aclImdb/test/all/408_7.txt'),
#   PosixPath('aclImdb/test/all/11764_7.txt'),
#   PosixPath('aclImdb/test/all/5562_2.txt'),
#   PosixPath('aclImdb/test/all/1282_10.txt'),
#   PosixPath('aclImdb/test/all/2072_2.txt'),
#   PosixPath('aclImdb/test/all/11291_3.txt'),
#   PosixPath('aclImdb/test/all/3867_8.txt'),
#   PosixPath('aclImdb/test/all/9353_4.txt'),
#   PosixPath('aclImdb/test/all/11640_3.txt'),
#   PosixPath('aclImdb/test/all/9782_4.txt'),
#   PosixPath('aclImdb/test/all/3011_1.txt'),
#   PosixPath('aclImdb/test/all/12389_8.txt'),
#   PosixPath('aclImdb/test/all/9839_8.txt'),
#   PosixPath('aclImdb/test/all/6816_10.txt'),
#   PosixPath('aclImdb/test/all/2259_9.txt'),
#   ...])

# %%
def merge_files(folder_path: Path):
    raw_text = ""
    files = folder_path.ls()
    for file_path in files[:]:
        with file_path.open("r") as f:
            raw_text += "\n" + f.read()
    #             return(f.read())
    return raw_text

# %%
# %time train_text = merge_files(train_data_path)
# Out:
# CPU times: user 3.23 s, sys: 3.75 s, total: 6.98 s
# Wall time: 13.4 s

# %%
# %time test_text = merge_files(test_data_path)
# Out:
# CPU times: user 1.03 s, sys: 1.25 s, total: 2.28 s
# Wall time: 4.42 s

# %%
movie_reviews = train_text + "\n" + test_text
del(train_text)
del(test_text)

# %%
movie_reviews.__sizeof__(), len(movie_reviews)
# Out:
# (264133428, 132066677)

# %%
with open("Movie_Reviews.txt", "w") as f:
        f.write(movie_reviews)

# %%
# !wc -l Movie_Reviews.txt
# Out:
#   100001 Movie_Reviews.txt

# %% [markdown]
# # Preparing Wiki Data
# This is about 3.7G of download, so it took about 30 minutes for me to download.
#
# Your download time might vary, depending on your Internet speeds.

# %%
# !wget -c "http://files.fast.ai/data/enwiki.tgz"
# Out:
# --2020-05-21 11:02:37--  http://files.fast.ai/data/enwiki.tgz
# Resolving files.fast.ai (files.fast.ai)... 67.205.15.147
# Connecting to files.fast.ai (files.fast.ai)|67.205.15.147|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4009981337 (3.7G) [application/x-gtar-compressed]
# Saving to: ‘enwiki.tgz’
#
# enwiki.tgz          100%[===================>]   3.73G  7.80MB/s    in 10m 21s
#
# 2020-05-21 11:12:59 (6.16 MB/s) - ‘enwiki.tgz’ saved [4009981337/4009981337]

# %% [markdown]
# The next step takes a moment. This is on silent mode, no verbose print outs. This took about 10 minutes on my local machine.

# %%
# !tar -xzf enwiki.tgz

# %%
# !head enwiki
# Out:
# <doc id="12" url="https://en.wikipedia.org/wiki?curid=12" title="Anarchism">
# Anarchism
#
# Anarchism is an anti-authoritarian political philosophy that advocates self-managed, self-governed societies based on voluntary, cooperative institutions and the rejection of hierarchies those societies view as unjust. These institutions are often described as stateless societies, although several authors have defined them more specifically as distinct institutions based on non-hierarchical or free associations. Anarchism's central disagreement with other ideologies is that it holds the state to be undesirable, unnecessary, and harmful.
#
# Anarchism is usually placed on the far-left of the political spectrum, and much of its economics and legal philosophy reflect anti-authoritarian interpretations of communism, collectivism, syndicalism, mutualism, or participatory economics. As anarchism does not offer a fixed body of doctrine from a single particular worldview, many anarchist types and traditions exist and varieties of anarchy diverge widely. Anarchist schools of thought can differ fundamentally, supporting anything from extreme individualism to complete collectivism. Strains of anarchism have often been divided into the categories of social and individualist anarchism, or similar dual classifications.
#
# The etymological origin of anarchism derives from ancient Greek word "anarkhia". "Anarkhia" meant "without a ruler" as it was composed by the prefix a (i.e. "without") and the word "arkhos" (i.e. leader or ruler). The suffix -ism is used to denote the ideological current that favours anarchism. The first known use of this word was in 1642. Various factions within the French Revolution labelled opponents as anarchists although few shared many views of later anarchists. There would be many revolutionaries of the early 19th century who contributed to the anarchist doctrines of the next generation, such as William Godwin and Wilhelm Weitling, but they did not use the word anarchist or anarchism in describing themselves or their beliefs.
#
# The first political philosopher to call himself an anarchist was Pierre-Joseph Proudhon, marking the formal birth of anarchism in the mid-19th century. Since the 1890s and beginning in France, the term libertarianism has often been used as a synonym for anarchism and its use as a synonym is still common outside the United States. On the other hand, some use libertarianism to refer to individualistic free-market philosophy only, referring to free-market anarchism as libertarian anarchism.
