# %%
# !pip install nlp
# !pip install bert_score
# !pip install git+https://github.com/google-research/bleurt.git
from pathlib import Path

import pandas as pd
import asyncio
import aiohttp
import json
from aiohttp import ClientConnectorError, ClientSession
from nlp import load_metric
from sklearn.model_selection import train_test_split
from tqdm.notebook import tqdm

# %%
data_path = Path("../data")
assert data_path.exists()
datagen_path = Path("../data/datageneration")
assert datagen_path.exists()
keys_path = Path("key.json")
assert keys_path.exists()

# %%
data = pd.read_json(datagen_path/"reasons.json")
s = data.apply(lambda x: pd.Series(x['Reasons']),axis=1).stack().reset_index(level=1, drop=True)
s.name = 'Reason'
data = data.drop('Reasons', axis=1).join(s)
data.Reason = data.Reason.apply(lambda x : x.replace("\nReason : ", "").replace("\n", "").replace( "Because ", ""))
data
# Out:
#                       Input Sentence              Intent  \
# 0   I would like to Activate my card          Activation
# 0   I would like to Activate my card          Activation
# 0   I would like to Activate my card          Activation
# 0   I would like to Activate my card          Activation
# 0   I would like to Activate my card          Activation
# ..                               ...                 ...
# 44          change my phone passcode  e-PIN modification
# 44          change my phone passcode  e-PIN modification
# 44          change my phone passcode  e-PIN modification
# 44          change my phone passcode  e-PIN modification
# 44          change my phone passcode  e-PIN modification
#
#                               Reason
# 0          I want to use it in Italy
# 0                   I need to use it
# 0             my card is not working
# 0         I have not receive my card
# 0   I want to do online transactions
# ..                               ...
# 44               I lost or forgot it
# 44             I forgot the passcode
# 44                         I lost it
# 44                          I forgot
# 44            I am changing my phone
#
# [5950 rows x 3 columns]

# %%
# data.sample(10).to_json(data_path/"prompts/IntentWithReason.json", indent=2, index=False, orient="table")

# %%
def prompt_generation(prompt_path):
    prompt = json.load(open(prompt_path))
    prompt = list(prompt)
    output = []
    for ele in prompt:
        for key, value in ele.items():
            output.append(f"{key} : {value}\n")
    return "".join(output)
prompt_path = data_path/"prompts/IntentWithReason.json"
prompt_generation(prompt_path)
# Out:
# "Input Sentence : When is my credit card/covered card payment due\nContext : Bank\nIntent : Payment due Date\nReason : I want to check my payment status\nStructure : InformalWithoutGreetings, IntentFirst, WithReason\nSentence : I want to know payment due date because I want to check my payment status\nInput Sentence : Pay my <<vendor>> bill\nContext : Bank\nIntent : Bill Payment\nReason : I want to pay\nStructure : FormalWithGreetings, ReasonFirst\nSentence : Hello, I want to pay so I want to know more about bill payment, Thank you.\nInput Sentence : You have any covered card/credit card promotions?\nContext : Bank\nIntent : Promotion\nReason : I want to compare\nStructure : FormalWithGreetings, WithoutReason\nSentence : Hello, I want to know more about promotions, Thanks a lot.\nInput Sentence : I would like to donate to Zakat\nContext : Bank\nIntent : Donation\nReason : I have surplus money\nStructure : FormalWithGreetings, WithReason, IntentFirst\nSentence : Hi, I would like to donate to Zakat because I have surplus money, Regards\nInput Sentence : Check my instalment\nContext : Bank\nIntent : Balance\nReason : I want to check the balance\nStructure : InformalWithoutGreetings, WithoutReason, IntentFirst\nSentence : I want 2 check balance\nInput Sentence : Check my Finance Murabaha Outstanding Balance\nContext : Bank\nIntent : Balance\nReason : I want to know how much is my outstanding balance\nStructure : FormalWithGreetings, ReasonFirst\nSentence : HELLO, I want to know how much is my outstanding balance so can you plz help with infromation about balance, THANK YOU\nInput Sentence : Send me covered card statement\nContext : Bank\nIntent : Covered Card e-statement\nReason : I forgot to print it\nStructure : InformalWithoutGreetings, IntentFirst, WithReason\nSentence : Send me covered card e-statement because I forgot to print it.\nInput Sentence : When was my last instalment paid\nContext : Bank\nIntent : Instalment Payment\nReason : I want to check the payment\nStructure : InformalWithoutGreetings, WithoutReason, WithTypos\nSentence : Wen was my last instalment paid\nInput Sentence : Available limit\nContext : Bank\nIntent : Available Limit\nReason : I want to know how much money I have\nStructure : WithReason, ReasonFirst, WithTypos\nSentence : I want to know how much money I hav tell me about avialiable limit\nInput Sentence : What was the last Credit transaction on my covered card\nContext : Bank\nIntent : Covered Card Transaction\nReason : To see if it's working\nStructure : WithReason, FormalWithGreetings\nSentence : Hello, Good Morning, I wanted to know what was the last Credit transaction on my covered card because I want to see if it's working\n"

# %%
async def make_requests_completions(query_list, prompt) -> None:
    async with ClientSession() as session:
        tasks = []
        url = "https://api.openai.com/v1/engines/curie/completions"
        for query in query_list:
            tasks.append(
                fetch_GPT3_completion_response(
                    url=url, session=session, prompt=prompt, query=query,
                )
            )
        results = [await f for f in tqdm(asyncio.as_completed(tasks), total=len(tasks))]
    return results

# %%
async def fetch_GPT3_completion_response(
    url: str, session: ClientSession, prompt, query
) -> tuple:
    headers = {
        "Content-Type": "application/json",
        "Authorization": f'Bearer {json.load(keys_path.open("r"))["api_key"]}',
    }
    try:
        prompt += query["Prompt"]
        data = json.dumps(
            {
                "prompt": prompt,
                "max_tokens": 50,
                "temperature": 0.55,
                "frequency_penalty": 0.80,
                "presence_penalty": 0.80,
                "stop" : "Input Sentence",
#                 "echo": True
            }
        )
        resp = await session.request(method="POST", url=url, headers=headers, data=data)
    except ClientConnectorError:
        return ("error", row.MessageId, query_intent)
    r = await resp.json()
    try: 
        output = {
           "Structure" : r["choices"][0]["text"].split("\n")[1].replace("Structure : ", ""),
            "Sentence" : r["choices"][0]["text"].split("\n")[2].replace("Sentence :", ""),
            "Input Sentence" : query["Input Sentence"],
            "Intent" : query["Intent"],
            "Reason" : query["Reason"]
        }
        return output
    except :

        return {
            "Structure" : "NA",
            "Sentence"  : "NA",
        }

# %%
results = await make_requests_completions(
    query_list=[
        {
            "Prompt" : f"""Input Sentence : {row["Input Sentence"]}\nContext : Bank\nIntent : {row['Intent']}\nReason : {row['Reason']}""",
            "Input Sentence" : row["Input Sentence"],
            "Intent" : row["Intent"],
            "Reason" : row["Reason"]
        }
        for _, row in data.iterrows()
    ],
    prompt=prompt_generation(prompt_path),
)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=5950.0), HTML(value='')))

# %%
df = pd.DataFrame(results)
df
# Out:
#                                          Structure  \
# 0                  WithReason, FormalWithGreetings
# 1                  WithReason, FormalWithGreetings
# 2                  WithReason, FormalWithGreetings
# 3                  WithReason, FormalWithGreetings
# 4                 FormalWithGreetings, ReasonFirst
# ...                                            ...
# 5945              FormalWithGreetings, ReasonFirst
# 5946               WithReason, FormalWithGreetings
# 5947               WithReason, FormalWithGreetings
# 5948  FormalWithGreetings, WithReason, ReasonFirst
# 5949               WithReason, FormalWithGreetings
#
#                                                Sentence  \
# 0      Hello, Good Morning, I wanted to know what wa...
# 1      Hello, Good Morning, I wanted to know what wa...
# 2      Hello, Good Morning, I wanted to know what wa...
# 3      Hello, Good Morning, I wanted to know what wa...
# 4      Hello, Good Morning, I wanted to know what wa...
# ...                                                 ...
# 5945   Hello, Good Morning, I wanted to know what wa...
# 5946   Hello, Good Morning, I wanted to know what wa...
# 5947   Hello, Good Morning, I wanted to know what wa...
# 5948   Hello I want to know what was the last transa...
# 5949   Hello, Good Morning, I wanted to know what wa...
#
#                                          Input Sentence             Intent  \
# 0     What was the last debit transaction on my Debi...  Debit Transaction
# 1     What was the last debit transaction on my Debi...  Debit Transaction
# 2     What was the last debit transaction on my Debi...  Debit Transaction
# 3     What was the last debit transaction on my Debi...  Debit Transaction
# 4     What was the last debit transaction on my Debi...  Debit Transaction
# ...                                                 ...                ...
# 5945  What was the last debit transaction on my Debi...  Debit Transaction
# 5946  What was the last debit transaction on my Debi...  Debit Transaction
# 5947  What was the last debit transaction on my Debi...  Debit Transaction
# 5948  What was the last debit transaction on my Debi...  Debit Transaction
# 5949  What was the last debit transaction on my Debi...  Debit Transaction
#
#                                                  Reason
# 0                   I need to know the last transaction
# 1                       I want to check my transactions
# 2                                   To check my balance
# 3                    I want to see if my friend used it
# 4     I want to know what was the last transaction o...
# ...                                                 ...
# 5945       I want to check what was my last transaction
# 5946             I want to check if I have been scammed
# 5947                    I want to check if it's my card
# 5948  I want to know what was the last transaction done
# 5949  I want to check if someone used my card withou...
#
# [5950 rows x 5 columns]

# %%
df.to_json(datagen_path/"SentencesUsingReasons.json", indent=2)

# %%
from nlp import load_metric
metric = load_metric("bertscore")

# %%
df.dropna(inplace = True)
metric.compute(df["Input Sentence"], df["Sentence"], lang="en")
# Out:
# Warning: Empty reference sentence detected; setting recall to be 0.
# {'precision': tensor([0.9287, 0.9295, 0.9320,  ..., 0.9267, 0.9413, 0.9431]),
#  'recall': tensor([0.8765, 0.8731, 0.8756,  ..., 0.8656, 0.8899, 0.8748]),
#  'f1': tensor([0.9018, 0.9004, 0.9029,  ..., 0.8951, 0.9149, 0.9076]),
#  'hashcode': 'roberta-large_L17_no-idf_version=0.3.5(hug_trans=3.0.2)'}

# %%
json.dump(results, open(datagen_path/"SentencesUsingReasons.json", "w"), indent=2)
